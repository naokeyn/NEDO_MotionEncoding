# %%
import os, json
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

import scipy.io as sio
from sklearn.model_selection import KFold

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("..")
from src.preprocess import EmgEncoder
from src.model import ResNet1d
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## データの前処理

# %%
reference = sio.loadmat("../data/reference.mat")

train_encoder = EmgEncoder()
train_x = reference["0005"][0][0][0]
train_y = reference["0005"][0][0][1]
test_x = reference["0005"][0][0][2]
test_y = reference["0005"][0][0][3]

train_x = train_encoder.fit_transform(train_x)
y_scaler = [train_y.max(), train_y.min()]
train_y = (train_y - y_scaler[1]) / (y_scaler[0] - y_scaler[1])
train_y = train_y.transpose(0, 2, 1)

test_x = train_encoder.transform(test_x)
test_y = (test_y - y_scaler[1]) / (y_scaler[0] - y_scaler[1])
test_y = test_y.transpose(0, 2, 1)

train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((320, 1000, 16), (320, 1000, 16), (320, 30, 3), (320, 30, 3))

# %% [markdown]
# ## モデルの定義

# %%
def compile_model(dropout: float=0.1, learning_rate: float=10e-3):
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(16000, 32000, dtype=torch.float32),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(32000, 1000, dtype=torch.float32),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(1000, 500, dtype=torch.float32),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(500, 100, dtype=torch.float32),
        nn.Dropout(dropout),
        # nn.ReLU(),
        nn.Tanh(),
        nn.Linear(100, 30, dtype=torch.float32)
    )   
    loss_function = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    return model, optimizer, loss_function

def compile_model2(dropout: float=0.2, learning_rate: float=10e-3):
    model = nn.Sequential(
        nn.Conv1d(in_channels=16, out_channels=64, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.AdaptiveMaxPool1d(30),
        nn.Flatten(start_dim=1),
        nn.Linear(128*30, 30),
    )
    loss_function = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    return model, optimizer, loss_function

def compile_model3(dropout: float=0.2, learning_rate: float=10e-3):
    model = nn.Sequential(
        # Conv1D層1: 入力チャンネル16 -> 出力チャンネル64
        nn.Conv1d(in_channels=16, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm1d(64),  # バッチ正規化
        nn.ReLU(),
        
        # Conv1D層2: 入力チャンネル64 -> 出力チャンネル128
        nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.BatchNorm1d(128),  # バッチ正規化
        nn.ReLU(),
        
        # Conv1D層3: 入力チャンネル128 -> 出力チャンネル256
        nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
        nn.BatchNorm1d(256),  # バッチ正規化
        nn.ReLU(),
        
        # プーリング層で時系列を30に縮小
        nn.AdaptiveMaxPool1d(30),
        
        nn.Flatten(start_dim=1),
        
        # 全結合層1: 入力256 * 30 -> 隠れ層512
        nn.Linear(256 * 30, 512),
        nn.Tanh(),
        nn.Dropout(dropout),        
        nn.Linear(512, 30)
    )

    # 損失関数と最適化関数
    loss_function = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    return model, optimizer, loss_function

def train_1epoch(model, loss_fn, optimizer, train_loader):
    total_loss = 0
    for i, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        pred = model(x)
        loss = loss_fn(pred, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    return total_loss / len(train_loader)

def valid_1epoch(model, loss_fn, valid_loader):
    total_loss = 0
    with torch.no_grad():
        for i, (x, y) in enumerate(valid_loader):
            x = x.to(device)
            y = y.to(device)
            pred = model(x)
            total_loss += loss_fn(pred, y).item()
        
    return total_loss / len(valid_loader)

def predict(model, test_loader):
    results = {"true": [], "pred": []}
    with torch.no_grad():
        for i, (x, y) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            pred = model(x)

            results["true"].append(y.to("cpu"))
            results["pred"].append(pred.to("cpu"))
    return results

# %% [markdown]
# ## Datasetの作成

# %%
class RefDataset(torch.utils.data.Dataset):
    def __init__(self, x, y, y_axis: int=0):
        super().__init__()
        self.x = x
        self.y = y
        self.y_axis = y_axis
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x = torch.tensor(self.x[idx, :, :].transpose(1, 0), dtype=torch.float32)
        y = torch.tensor(self.y[idx, :, self.y_axis], dtype=torch.float32)
        
        return x, y

# %% [markdown]
# ## KFold CV

# %%
batch_size = 30
dropout = 0.3
epochs = 100
hidden_state = [32000, 1000, 500, 100]
learning_rate = 10e-3
num_layers = 4
num_splits = 5
num_workers = 12

axis = 2

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

dataset = RefDataset(train_x, train_y, y_axis=0)
test_dataset = RefDataset(test_x, test_y, y_axis=axis)

pred_results = []
history = []
kf = KFold(n_splits=num_splits, shuffle=True, random_state=42)
for i, (train_idx, valid_idx) in enumerate(kf.split(range(len(dataset)))):
    train_dataset = torch.utils.data.Subset(dataset, train_idx)
    valid_dataset = torch.utils.data.Subset(dataset, valid_idx)
    
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        shuffle=True
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        shuffle=False
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=1,
        num_workers=num_workers,
        shuffle=False
    )
    
    # model, optimizer, loss_fn = compile_model(dropout=dropout, num_layer=num_layers, hidden_state=hidden_state)
    model, optimizer, loss_fn = compile_model2(dropout=dropout, learning_rate=learning_rate)
    # model, optimizer, loss_fn = compile_model3(dropout=dropout)
    
    model.to(device)
    history_1epoch = {"train": [], "valid": []}
    best_value = 10e9
    best_epoch = 0
    for epoch in tqdm(range(epochs)):
        model.train()
        train_loss = train_1epoch(model, loss_fn, optimizer, train_loader)
        model.eval()
        valid_loss = valid_1epoch(model, loss_fn, valid_loader)
        print(f"[Epoch {epoch}] train loss: {train_loss:.5f}, valid loss: {valid_loss:.5f}")
        history_1epoch["train"].append(train_loss)
        history_1epoch["valid"].append(valid_loss)
        
        if valid_loss < best_value:
            print(f"+++++ Saved as Best-Epoch: {epoch} ++++++")
            torch.save(model, f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
            best_value = valid_loss
            best_epoch = epoch
            
        
    results = predict(model, test_loader)
    pred_results.append(results)
    history.append(history_1epoch)
    
    torch.save(model, f"../models/Fold{i}_Axis{axis}_FinalEpoch.pt")
    print("=======================================")
    print(f"  Best epoch: {best_epoch}, valid loss: {best_value:.5f}")
    print("=======================================")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 4.26787, valid loss: 0.10741
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.10912, valid loss: 0.08580
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.07516, valid loss: 0.07433
# +++++ Saved as Best-Epoch: 2 ++++++
# [Epoch 3] train loss: 0.06244, valid loss: 0.07108
# +++++ Saved as Best-Epoch: 3 ++++++
# [Epoch 4] train loss: 0.06814, valid loss: 0.04859
# +++++ Saved as Best-Epoch: 4 ++++++
# [Epoch 5] train loss: 0.05431, valid loss: 0.04664
# +++++ Saved as Best-Epoch: 5 ++++++
# [Epoch 6] train loss: 0.04511, valid loss: 0.05218
# [Epoch 7] train loss: 0.04913, valid loss: 0.13280
# [Epoch 8] train loss: 0.08746, valid loss: 0.06580
# [Epoch 9] train loss: 0.05613, valid loss: 0.06342
# [Epoch 10] train loss: 0.05273, valid loss: 0.04438
# +++++ Saved as Best-Epoch: 10 ++++++
# [Epoch 11] train loss: 0.03433, valid loss: 0.04961
# [Epoch 12] train loss: 0.03303, valid loss: 0.02781
# +++++ Saved as Best-Epoch: 12 ++++++
# [Epoch 13] train loss: 0.02686, valid loss: 0.02666
# +++++ Saved as Best-Epoch: 13 ++++++
# [Epoch 14] train loss: 0.02531, valid loss: 0.02937
# [Epoch 15] train loss: 0.02243, valid loss: 0.03142
# [Epoch 16] train loss: 0.02323, valid loss: 0.02563
# +++++ Saved as Best-Epoch: 16 ++++++
# [Epoch 17] train loss: 0.02497, valid loss: 0.03301
# [Epoch 18] train loss: 0.02232, valid loss: 0.02459
# +++++ Saved as Best-Epoch: 18 ++++++
# [Epoch 19] train loss: 0.02412, valid loss: 0.03727
# [Epoch 20] train loss: 0.02670, valid loss: 0.02884
# [Epoch 21] train loss: 0.02419, valid loss: 0.06375
# [Epoch 22] train loss: 0.02748, valid loss: 0.03118
# [Epoch 23] train loss: 0.02746, valid loss: 0.04822
# [Epoch 24] train loss: 0.03165, valid loss: 0.02344
# +++++ Saved as Best-Epoch: 24 ++++++
# [Epoch 25] train loss: 0.02136, valid loss: 0.04088
# [Epoch 26] train loss: 0.02450, valid loss: 0.02505
# [Epoch 27] train loss: 0.02070, valid loss: 0.02218
# +++++ Saved as Best-Epoch: 27 ++++++
# [Epoch 28] train loss: 0.01903, valid loss: 0.02217
# +++++ Saved as Best-Epoch: 28 ++++++
# [Epoch 29] train loss: 0.01851, valid loss: 0.02311
# [Epoch 30] train loss: 0.01985, valid loss: 0.02960
# [Epoch 31] train loss: 0.01553, valid loss: 0.02109
# +++++ Saved as Best-Epoch: 31 ++++++
# [Epoch 32] train loss: 0.01611, valid loss: 0.02202
# [Epoch 33] train loss: 0.01539, valid loss: 0.02887
# [Epoch 34] train loss: 0.01562, valid loss: 0.02655
# [Epoch 35] train loss: 0.01455, valid loss: 0.02049
# +++++ Saved as Best-Epoch: 35 ++++++
# [Epoch 36] train loss: 0.01341, valid loss: 0.01973
# +++++ Saved as Best-Epoch: 36 ++++++
# [Epoch 37] train loss: 0.01464, valid loss: 0.02647
# [Epoch 38] train loss: 0.01406, valid loss: 0.02198
# [Epoch 39] train loss: 0.01490, valid loss: 0.02200
# [Epoch 40] train loss: 0.01854, valid loss: 0.02910
# [Epoch 41] train loss: 0.01647, valid loss: 0.01922
# +++++ Saved as Best-Epoch: 41 ++++++
# [Epoch 42] train loss: 0.01643, valid loss: 0.03179
# [Epoch 43] train loss: 0.01976, valid loss: 0.03182
# [Epoch 44] train loss: 0.02282, valid loss: 0.02119
# [Epoch 45] train loss: 0.01333, valid loss: 0.01832
# +++++ Saved as Best-Epoch: 45 ++++++
# [Epoch 46] train loss: 0.01266, valid loss: 0.01958
# [Epoch 47] train loss: 0.01136, valid loss: 0.01676
# +++++ Saved as Best-Epoch: 47 ++++++
# [Epoch 48] train loss: 0.01146, valid loss: 0.01767
# [Epoch 49] train loss: 0.01084, valid loss: 0.02594
# [Epoch 50] train loss: 0.01476, valid loss: 0.02492
# [Epoch 51] train loss: 0.02187, valid loss: 0.02204
# [Epoch 52] train loss: 0.01977, valid loss: 0.04416
# [Epoch 53] train loss: 0.02638, valid loss: 0.02845
# [Epoch 54] train loss: 0.02004, valid loss: 0.05174
# [Epoch 55] train loss: 0.01982, valid loss: 0.01956
# [Epoch 56] train loss: 0.01365, valid loss: 0.02159
# [Epoch 57] train loss: 0.01087, valid loss: 0.01739
# [Epoch 58] train loss: 0.01014, valid loss: 0.01666
# +++++ Saved as Best-Epoch: 58 ++++++
# [Epoch 59] train loss: 0.00977, valid loss: 0.01829
# [Epoch 60] train loss: 0.01026, valid loss: 0.03279
# [Epoch 61] train loss: 0.01575, valid loss: 0.01797
# [Epoch 62] train loss: 0.01280, valid loss: 0.01914
# [Epoch 63] train loss: 0.01327, valid loss: 0.02340
# [Epoch 64] train loss: 0.01180, valid loss: 0.01834
# [Epoch 65] train loss: 0.01167, valid loss: 0.03691
# [Epoch 66] train loss: 0.01161, valid loss: 0.01930
# [Epoch 67] train loss: 0.01208, valid loss: 0.02941
# [Epoch 68] train loss: 0.01127, valid loss: 0.01690
# [Epoch 69] train loss: 0.01470, valid loss: 0.02457
# [Epoch 70] train loss: 0.01135, valid loss: 0.01637
# +++++ Saved as Best-Epoch: 70 ++++++
# [Epoch 71] train loss: 0.01214, valid loss: 0.03086
# [Epoch 72] train loss: 0.01329, valid loss: 0.01675
# [Epoch 73] train loss: 0.01104, valid loss: 0.01633
# +++++ Saved as Best-Epoch: 73 ++++++
# [Epoch 74] train loss: 0.01171, valid loss: 0.01885
# [Epoch 75] train loss: 0.00939, valid loss: 0.01733
# [Epoch 76] train loss: 0.01155, valid loss: 0.03377
# [Epoch 77] train loss: 0.01184, valid loss: 0.01614
# +++++ Saved as Best-Epoch: 77 ++++++
# [Epoch 78] train loss: 0.00958, valid loss: 0.01498
# +++++ Saved as Best-Epoch: 78 ++++++
# [Epoch 79] train loss: 0.00867, valid loss: 0.01623
# [Epoch 80] train loss: 0.00759, valid loss: 0.01719
# [Epoch 81] train loss: 0.00773, valid loss: 0.01815
# [Epoch 82] train loss: 0.00934, valid loss: 0.01858
# [Epoch 83] train loss: 0.00798, valid loss: 0.02020
# [Epoch 84] train loss: 0.00777, valid loss: 0.01854
# [Epoch 85] train loss: 0.00954, valid loss: 0.01715
# [Epoch 86] train loss: 0.01032, valid loss: 0.02493
# [Epoch 87] train loss: 0.00986, valid loss: 0.02026
# [Epoch 88] train loss: 0.01076, valid loss: 0.01982
# [Epoch 89] train loss: 0.00967, valid loss: 0.01948
# [Epoch 90] train loss: 0.00813, valid loss: 0.01989
# [Epoch 91] train loss: 0.00778, valid loss: 0.01439
# +++++ Saved as Best-Epoch: 91 ++++++
# [Epoch 92] train loss: 0.00875, valid loss: 0.01520
# [Epoch 93] train loss: 0.00851, valid loss: 0.01874
# [Epoch 94] train loss: 0.00780, valid loss: 0.01961
# [Epoch 95] train loss: 0.00927, valid loss: 0.02582
# [Epoch 96] train loss: 0.00791, valid loss: 0.01590
# [Epoch 97] train loss: 0.00947, valid loss: 0.02297
# [Epoch 98] train loss: 0.00961, valid loss: 0.01621
# [Epoch 99] train loss: 0.00667, valid loss: 0.01805
# =======================================
#   Best epoch: 91, valid loss: 0.01439
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 2.23199, valid loss: 0.08580
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.11911, valid loss: 0.10405
# [Epoch 2] train loss: 0.10763, valid loss: 0.08787
# [Epoch 3] train loss: 0.10100, valid loss: 0.07964
# +++++ Saved as Best-Epoch: 3 ++++++
# [Epoch 4] train loss: 0.09577, valid loss: 0.09532
# [Epoch 5] train loss: 0.09451, valid loss: 0.06961
# +++++ Saved as Best-Epoch: 5 ++++++
# [Epoch 6] train loss: 0.08221, valid loss: 0.05662
# +++++ Saved as Best-Epoch: 6 ++++++
# [Epoch 7] train loss: 0.06167, valid loss: 0.03784
# +++++ Saved as Best-Epoch: 7 ++++++
# [Epoch 8] train loss: 0.05152, valid loss: 0.05447
# [Epoch 9] train loss: 0.05348, valid loss: 0.02776
# +++++ Saved as Best-Epoch: 9 ++++++
# [Epoch 10] train loss: 0.05740, valid loss: 0.02907
# [Epoch 11] train loss: 0.04126, valid loss: 0.03188
# [Epoch 12] train loss: 0.04365, valid loss: 0.02237
# +++++ Saved as Best-Epoch: 12 ++++++
# [Epoch 13] train loss: 0.03705, valid loss: 0.03945
# [Epoch 14] train loss: 0.03513, valid loss: 0.01960
# +++++ Saved as Best-Epoch: 14 ++++++
# [Epoch 15] train loss: 0.03434, valid loss: 0.01847
# +++++ Saved as Best-Epoch: 15 ++++++
# [Epoch 16] train loss: 0.03041, valid loss: 0.03455
# [Epoch 17] train loss: 0.03667, valid loss: 0.01904
# [Epoch 18] train loss: 0.03437, valid loss: 0.01838
# +++++ Saved as Best-Epoch: 18 ++++++
# [Epoch 19] train loss: 0.03288, valid loss: 0.01772
# +++++ Saved as Best-Epoch: 19 ++++++
# [Epoch 20] train loss: 0.03173, valid loss: 0.07225
# [Epoch 21] train loss: 0.06952, valid loss: 0.06590
# [Epoch 22] train loss: 0.04997, valid loss: 0.02530
# [Epoch 23] train loss: 0.04571, valid loss: 0.02958
# [Epoch 24] train loss: 0.03540, valid loss: 0.03803
# [Epoch 25] train loss: 0.03046, valid loss: 0.01718
# +++++ Saved as Best-Epoch: 25 ++++++
# [Epoch 26] train loss: 0.02631, valid loss: 0.03035
# [Epoch 27] train loss: 0.02869, valid loss: 0.01708
# +++++ Saved as Best-Epoch: 27 ++++++
# [Epoch 28] train loss: 0.03432, valid loss: 0.01803
# [Epoch 29] train loss: 0.02680, valid loss: 0.01998
# [Epoch 30] train loss: 0.02526, valid loss: 0.02238
# [Epoch 31] train loss: 0.03313, valid loss: 0.02697
# [Epoch 32] train loss: 0.03346, valid loss: 0.02159
# [Epoch 33] train loss: 0.02458, valid loss: 0.01965
# [Epoch 34] train loss: 0.02583, valid loss: 0.02309
# [Epoch 35] train loss: 0.03153, valid loss: 0.02285
# [Epoch 36] train loss: 0.02862, valid loss: 0.01868
# [Epoch 37] train loss: 0.02510, valid loss: 0.01817
# [Epoch 38] train loss: 0.02382, valid loss: 0.01901
# [Epoch 39] train loss: 0.02230, valid loss: 0.02154
# [Epoch 40] train loss: 0.02362, valid loss: 0.03888
# [Epoch 41] train loss: 0.03433, valid loss: 0.01782
# [Epoch 42] train loss: 0.02920, valid loss: 0.01764
# [Epoch 43] train loss: 0.02520, valid loss: 0.01789
# [Epoch 44] train loss: 0.02349, valid loss: 0.01747
# [Epoch 45] train loss: 0.02400, valid loss: 0.01963
# [Epoch 46] train loss: 0.02120, valid loss: 0.01750
# [Epoch 47] train loss: 0.02265, valid loss: 0.01791
# [Epoch 48] train loss: 0.02194, valid loss: 0.02264
# [Epoch 49] train loss: 0.02597, valid loss: 0.01744
# [Epoch 50] train loss: 0.02248, valid loss: 0.01841
# [Epoch 51] train loss: 0.02384, valid loss: 0.01852
# [Epoch 52] train loss: 0.02344, valid loss: 0.01904
# [Epoch 53] train loss: 0.02109, valid loss: 0.02159
# [Epoch 54] train loss: 0.02357, valid loss: 0.02104
# [Epoch 55] train loss: 0.02771, valid loss: 0.03745
# [Epoch 56] train loss: 0.02487, valid loss: 0.01752
# [Epoch 57] train loss: 0.02464, valid loss: 0.01747
# [Epoch 58] train loss: 0.02044, valid loss: 0.01857
# [Epoch 59] train loss: 0.02516, valid loss: 0.02034
# [Epoch 60] train loss: 0.02393, valid loss: 0.01758
# [Epoch 61] train loss: 0.02114, valid loss: 0.02509
# [Epoch 62] train loss: 0.02510, valid loss: 0.01867
# [Epoch 63] train loss: 0.02002, valid loss: 0.01909
# [Epoch 64] train loss: 0.02416, valid loss: 0.01820
# [Epoch 65] train loss: 0.02364, valid loss: 0.01761
# [Epoch 66] train loss: 0.02130, valid loss: 0.02953
# [Epoch 67] train loss: 0.02670, valid loss: 0.03108
# [Epoch 68] train loss: 0.02940, valid loss: 0.01746
# [Epoch 69] train loss: 0.02432, valid loss: 0.01849
# [Epoch 70] train loss: 0.02103, valid loss: 0.02783
# [Epoch 71] train loss: 0.02185, valid loss: 0.02009
# [Epoch 72] train loss: 0.01995, valid loss: 0.02263
# [Epoch 73] train loss: 0.02051, valid loss: 0.01709
# [Epoch 74] train loss: 0.02126, valid loss: 0.01953
# [Epoch 75] train loss: 0.02078, valid loss: 0.01939
# [Epoch 76] train loss: 0.02014, valid loss: 0.01712
# [Epoch 77] train loss: 0.02062, valid loss: 0.01772
# [Epoch 78] train loss: 0.01915, valid loss: 0.02251
# [Epoch 79] train loss: 0.02371, valid loss: 0.01798
# [Epoch 80] train loss: 0.01947, valid loss: 0.02683
# [Epoch 81] train loss: 0.02172, valid loss: 0.02145
# [Epoch 82] train loss: 0.01965, valid loss: 0.01937
# [Epoch 83] train loss: 0.01930, valid loss: 0.01756
# [Epoch 84] train loss: 0.01891, valid loss: 0.01869
# [Epoch 85] train loss: 0.01853, valid loss: 0.01813
# [Epoch 86] train loss: 0.02337, valid loss: 0.03179
# [Epoch 87] train loss: 0.02662, valid loss: 0.01757
# [Epoch 88] train loss: 0.02488, valid loss: 0.01718
# [Epoch 89] train loss: 0.02093, valid loss: 0.01925
# [Epoch 90] train loss: 0.01967, valid loss: 0.01784
# [Epoch 91] train loss: 0.01943, valid loss: 0.01701
# +++++ Saved as Best-Epoch: 91 ++++++
# [Epoch 92] train loss: 0.01971, valid loss: 0.04445
# [Epoch 93] train loss: 0.02894, valid loss: 0.02528
# [Epoch 94] train loss: 0.02771, valid loss: 0.02344
# [Epoch 95] train loss: 0.02531, valid loss: 0.02084
# [Epoch 96] train loss: 0.02030, valid loss: 0.01702
# [Epoch 97] train loss: 0.02116, valid loss: 0.03064
# [Epoch 98] train loss: 0.02915, valid loss: 0.02592
# [Epoch 99] train loss: 0.01841, valid loss: 0.01764
# =======================================
#   Best epoch: 91, valid loss: 0.01701
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 7.90501, valid loss: 0.11886
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.12590, valid loss: 0.08966
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.11106, valid loss: 0.08485
# +++++ Saved as Best-Epoch: 2 ++++++
# [Epoch 3] train loss: 0.10065, valid loss: 0.09903
# [Epoch 4] train loss: 0.09588, valid loss: 0.07795
# +++++ Saved as Best-Epoch: 4 ++++++
# [Epoch 5] train loss: 0.09637, valid loss: 0.07911
# [Epoch 6] train loss: 0.08496, valid loss: 0.07436
# +++++ Saved as Best-Epoch: 6 ++++++
# [Epoch 7] train loss: 0.07628, valid loss: 0.08430
# [Epoch 8] train loss: 0.07080, valid loss: 0.06651
# +++++ Saved as Best-Epoch: 8 ++++++
# [Epoch 9] train loss: 0.06444, valid loss: 0.05456
# +++++ Saved as Best-Epoch: 9 ++++++
# [Epoch 10] train loss: 0.06215, valid loss: 0.04606
# +++++ Saved as Best-Epoch: 10 ++++++
# [Epoch 11] train loss: 0.06259, valid loss: 0.04144
# +++++ Saved as Best-Epoch: 11 ++++++
# [Epoch 12] train loss: 0.05042, valid loss: 0.09417
# [Epoch 13] train loss: 0.04373, valid loss: 0.03895
# +++++ Saved as Best-Epoch: 13 ++++++
# [Epoch 14] train loss: 0.04367, valid loss: 0.05780
# [Epoch 15] train loss: 0.03691, valid loss: 0.03744
# +++++ Saved as Best-Epoch: 15 ++++++
# [Epoch 16] train loss: 0.03964, valid loss: 0.06403
# [Epoch 17] train loss: 0.04630, valid loss: 0.07298
# [Epoch 18] train loss: 0.03698, valid loss: 0.05184
# [Epoch 19] train loss: 0.03958, valid loss: 0.03591
# +++++ Saved as Best-Epoch: 19 ++++++
# [Epoch 20] train loss: 0.03475, valid loss: 0.03527
# +++++ Saved as Best-Epoch: 20 ++++++
# [Epoch 21] train loss: 0.03143, valid loss: 0.03448
# +++++ Saved as Best-Epoch: 21 ++++++
# [Epoch 22] train loss: 0.03613, valid loss: 0.07005
# [Epoch 23] train loss: 0.05116, valid loss: 0.03438
# +++++ Saved as Best-Epoch: 23 ++++++
# [Epoch 24] train loss: 0.04682, valid loss: 0.03567
# [Epoch 25] train loss: 0.03678, valid loss: 0.04527
# [Epoch 26] train loss: 0.03223, valid loss: 0.04606
# [Epoch 27] train loss: 0.03241, valid loss: 0.03332
# +++++ Saved as Best-Epoch: 27 ++++++
# [Epoch 28] train loss: 0.03083, valid loss: 0.04096
# [Epoch 29] train loss: 0.03145, valid loss: 0.04181
# [Epoch 30] train loss: 0.04073, valid loss: 0.03933
# [Epoch 31] train loss: 0.03364, valid loss: 0.06362
# [Epoch 32] train loss: 0.02962, valid loss: 0.03360
# [Epoch 33] train loss: 0.02695, valid loss: 0.04925
# [Epoch 34] train loss: 0.03053, valid loss: 0.02955
# +++++ Saved as Best-Epoch: 34 ++++++
# [Epoch 35] train loss: 0.02701, valid loss: 0.03505
# [Epoch 36] train loss: 0.02826, valid loss: 0.02936
# +++++ Saved as Best-Epoch: 36 ++++++
# [Epoch 37] train loss: 0.02656, valid loss: 0.04654
# [Epoch 38] train loss: 0.02937, valid loss: 0.02928
# +++++ Saved as Best-Epoch: 38 ++++++
# [Epoch 39] train loss: 0.02483, valid loss: 0.03060
# [Epoch 40] train loss: 0.02353, valid loss: 0.03174
# [Epoch 41] train loss: 0.02738, valid loss: 0.02829
# +++++ Saved as Best-Epoch: 41 ++++++
# [Epoch 42] train loss: 0.02862, valid loss: 0.02840
# [Epoch 43] train loss: 0.02709, valid loss: 0.04888
# [Epoch 44] train loss: 0.03257, valid loss: 0.02771
# +++++ Saved as Best-Epoch: 44 ++++++
# [Epoch 45] train loss: 0.02586, valid loss: 0.05513
# [Epoch 46] train loss: 0.02455, valid loss: 0.04033
# [Epoch 47] train loss: 0.02161, valid loss: 0.04085
# [Epoch 48] train loss: 0.02797, valid loss: 0.04935
# [Epoch 49] train loss: 0.02514, valid loss: 0.02738
# +++++ Saved as Best-Epoch: 49 ++++++
# [Epoch 50] train loss: 0.02235, valid loss: 0.02746
# [Epoch 51] train loss: 0.01962, valid loss: 0.03009
# [Epoch 52] train loss: 0.02025, valid loss: 0.03128
# [Epoch 53] train loss: 0.02575, valid loss: 0.02780
# [Epoch 54] train loss: 0.02180, valid loss: 0.04105
# [Epoch 55] train loss: 0.03140, valid loss: 0.02767
# [Epoch 56] train loss: 0.02294, valid loss: 0.03265
# [Epoch 57] train loss: 0.02162, valid loss: 0.03226
# [Epoch 58] train loss: 0.02257, valid loss: 0.02750
# [Epoch 59] train loss: 0.02498, valid loss: 0.03931
# [Epoch 60] train loss: 0.02651, valid loss: 0.02835
# [Epoch 61] train loss: 0.02400, valid loss: 0.04381
# [Epoch 62] train loss: 0.02137, valid loss: 0.02752
# [Epoch 63] train loss: 0.02090, valid loss: 0.02929
# [Epoch 64] train loss: 0.02156, valid loss: 0.02699
# +++++ Saved as Best-Epoch: 64 ++++++
# [Epoch 65] train loss: 0.02312, valid loss: 0.02761
# [Epoch 66] train loss: 0.02377, valid loss: 0.03321
# [Epoch 67] train loss: 0.02057, valid loss: 0.02938
# [Epoch 68] train loss: 0.01911, valid loss: 0.03459
# [Epoch 69] train loss: 0.01978, valid loss: 0.02688
# +++++ Saved as Best-Epoch: 69 ++++++
# [Epoch 70] train loss: 0.01981, valid loss: 0.03689
# [Epoch 71] train loss: 0.01825, valid loss: 0.02818
# [Epoch 72] train loss: 0.01876, valid loss: 0.02860
# [Epoch 73] train loss: 0.01903, valid loss: 0.02715
# [Epoch 74] train loss: 0.01833, valid loss: 0.02952
# [Epoch 75] train loss: 0.01961, valid loss: 0.03856
# [Epoch 76] train loss: 0.02195, valid loss: 0.03661
# [Epoch 77] train loss: 0.02808, valid loss: 0.04295
# [Epoch 78] train loss: 0.03446, valid loss: 0.07195
# [Epoch 79] train loss: 0.02437, valid loss: 0.02806
# [Epoch 80] train loss: 0.01918, valid loss: 0.02928
# [Epoch 81] train loss: 0.02403, valid loss: 0.02991
# [Epoch 82] train loss: 0.01869, valid loss: 0.02690
# [Epoch 83] train loss: 0.02103, valid loss: 0.02792
# [Epoch 84] train loss: 0.02310, valid loss: 0.04246
# [Epoch 85] train loss: 0.02015, valid loss: 0.03034
# [Epoch 86] train loss: 0.02338, valid loss: 0.03737
# [Epoch 87] train loss: 0.02173, valid loss: 0.02756
# [Epoch 88] train loss: 0.02278, valid loss: 0.02731
# [Epoch 89] train loss: 0.02184, valid loss: 0.03106
# [Epoch 90] train loss: 0.01912, valid loss: 0.03709
# [Epoch 91] train loss: 0.02002, valid loss: 0.02703
# [Epoch 92] train loss: 0.01690, valid loss: 0.02692
# [Epoch 93] train loss: 0.01979, valid loss: 0.05609
# [Epoch 94] train loss: 0.02145, valid loss: 0.02945
# [Epoch 95] train loss: 0.01770, valid loss: 0.02753
# [Epoch 96] train loss: 0.02249, valid loss: 0.05087
# [Epoch 97] train loss: 0.02210, valid loss: 0.02684
# +++++ Saved as Best-Epoch: 97 ++++++
# [Epoch 98] train loss: 0.02147, valid loss: 0.03673
# [Epoch 99] train loss: 0.01892, valid loss: 0.03123
# =======================================
#   Best epoch: 97, valid loss: 0.02684
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 1.23063, valid loss: 0.34850
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.15004, valid loss: 0.10953
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.10583, valid loss: 0.08473
# +++++ Saved as Best-Epoch: 2 ++++++
# [Epoch 3] train loss: 0.10543, valid loss: 0.08498
# [Epoch 4] train loss: 0.09741, valid loss: 0.08482
# [Epoch 5] train loss: 0.09147, valid loss: 0.07468
# +++++ Saved as Best-Epoch: 5 ++++++
# [Epoch 6] train loss: 0.08577, valid loss: 0.05802
# +++++ Saved as Best-Epoch: 6 ++++++
# [Epoch 7] train loss: 0.06263, valid loss: 0.05239
# +++++ Saved as Best-Epoch: 7 ++++++
# [Epoch 8] train loss: 0.05561, valid loss: 0.04275
# +++++ Saved as Best-Epoch: 8 ++++++
# [Epoch 9] train loss: 0.05549, valid loss: 0.03802
# +++++ Saved as Best-Epoch: 9 ++++++
# [Epoch 10] train loss: 0.05209, valid loss: 0.04171
# [Epoch 11] train loss: 0.04515, valid loss: 0.04366
# [Epoch 12] train loss: 0.04420, valid loss: 0.04579
# [Epoch 13] train loss: 0.03951, valid loss: 0.03271
# +++++ Saved as Best-Epoch: 13 ++++++
# [Epoch 14] train loss: 0.03705, valid loss: 0.03295
# [Epoch 15] train loss: 0.03286, valid loss: 0.03479
# [Epoch 16] train loss: 0.03485, valid loss: 0.03186
# +++++ Saved as Best-Epoch: 16 ++++++
# [Epoch 17] train loss: 0.02873, valid loss: 0.04883
# [Epoch 18] train loss: 0.04133, valid loss: 0.03855
# [Epoch 19] train loss: 0.03258, valid loss: 0.03187
# [Epoch 20] train loss: 0.03076, valid loss: 0.04444
# [Epoch 21] train loss: 0.02935, valid loss: 0.03506
# [Epoch 22] train loss: 0.02712, valid loss: 0.03341
# [Epoch 23] train loss: 0.02742, valid loss: 0.04348
# [Epoch 24] train loss: 0.02635, valid loss: 0.03651
# [Epoch 25] train loss: 0.03079, valid loss: 0.03001
# +++++ Saved as Best-Epoch: 25 ++++++
# [Epoch 26] train loss: 0.02641, valid loss: 0.03541
# [Epoch 27] train loss: 0.02837, valid loss: 0.05532
# [Epoch 28] train loss: 0.03195, valid loss: 0.03220
# [Epoch 29] train loss: 0.03179, valid loss: 0.03132
# [Epoch 30] train loss: 0.02543, valid loss: 0.03003
# [Epoch 31] train loss: 0.02439, valid loss: 0.03448
# [Epoch 32] train loss: 0.02587, valid loss: 0.02869
# +++++ Saved as Best-Epoch: 32 ++++++
# [Epoch 33] train loss: 0.02413, valid loss: 0.02978
# [Epoch 34] train loss: 0.02460, valid loss: 0.03193
# [Epoch 35] train loss: 0.02306, valid loss: 0.02846
# +++++ Saved as Best-Epoch: 35 ++++++
# [Epoch 36] train loss: 0.02269, valid loss: 0.03756
# [Epoch 37] train loss: 0.02843, valid loss: 0.02915
# [Epoch 38] train loss: 0.03478, valid loss: 0.07796
# [Epoch 39] train loss: 0.03316, valid loss: 0.02971
# [Epoch 40] train loss: 0.02617, valid loss: 0.03434
# [Epoch 41] train loss: 0.02269, valid loss: 0.02868
# [Epoch 42] train loss: 0.02621, valid loss: 0.02838
# +++++ Saved as Best-Epoch: 42 ++++++
# [Epoch 43] train loss: 0.02197, valid loss: 0.02861
# [Epoch 44] train loss: 0.02348, valid loss: 0.02898
# [Epoch 45] train loss: 0.02225, valid loss: 0.03762
# [Epoch 46] train loss: 0.03171, valid loss: 0.03152
# [Epoch 47] train loss: 0.02465, valid loss: 0.02914
# [Epoch 48] train loss: 0.02250, valid loss: 0.02954
# [Epoch 49] train loss: 0.02411, valid loss: 0.03350
# [Epoch 50] train loss: 0.02766, valid loss: 0.04144
# [Epoch 51] train loss: 0.03009, valid loss: 0.04044
# [Epoch 52] train loss: 0.04172, valid loss: 0.08715
# [Epoch 53] train loss: 0.04549, valid loss: 0.02876
# [Epoch 54] train loss: 0.02450, valid loss: 0.03416
# [Epoch 55] train loss: 0.02586, valid loss: 0.03068
# [Epoch 56] train loss: 0.02399, valid loss: 0.02783
# +++++ Saved as Best-Epoch: 56 ++++++
# [Epoch 57] train loss: 0.02648, valid loss: 0.03180
# [Epoch 58] train loss: 0.03412, valid loss: 0.02772
# +++++ Saved as Best-Epoch: 58 ++++++
# [Epoch 59] train loss: 0.02301, valid loss: 0.03486
# [Epoch 60] train loss: 0.02702, valid loss: 0.02863
# [Epoch 61] train loss: 0.02091, valid loss: 0.02945
# [Epoch 62] train loss: 0.01949, valid loss: 0.03002
# [Epoch 63] train loss: 0.02076, valid loss: 0.02884
# [Epoch 64] train loss: 0.02526, valid loss: 0.04765
# [Epoch 65] train loss: 0.02488, valid loss: 0.03815
# [Epoch 66] train loss: 0.02741, valid loss: 0.04849
# [Epoch 67] train loss: 0.02148, valid loss: 0.03011
# [Epoch 68] train loss: 0.02015, valid loss: 0.03124
# [Epoch 69] train loss: 0.01868, valid loss: 0.02956
# [Epoch 70] train loss: 0.01857, valid loss: 0.02900
# [Epoch 71] train loss: 0.01804, valid loss: 0.02858
# [Epoch 72] train loss: 0.02309, valid loss: 0.05553
# [Epoch 73] train loss: 0.02593, valid loss: 0.04755
# [Epoch 74] train loss: 0.03581, valid loss: 0.04155
# [Epoch 75] train loss: 0.02260, valid loss: 0.02890
# [Epoch 76] train loss: 0.01904, valid loss: 0.02932
# [Epoch 77] train loss: 0.01773, valid loss: 0.02916
# [Epoch 78] train loss: 0.01817, valid loss: 0.03063
# [Epoch 79] train loss: 0.01701, valid loss: 0.03035
# [Epoch 80] train loss: 0.01940, valid loss: 0.04371
# [Epoch 81] train loss: 0.01966, valid loss: 0.03482
# [Epoch 82] train loss: 0.01996, valid loss: 0.03152
# [Epoch 83] train loss: 0.02464, valid loss: 0.03268
# [Epoch 84] train loss: 0.02602, valid loss: 0.05210
# [Epoch 85] train loss: 0.02945, valid loss: 0.03343
# [Epoch 86] train loss: 0.01903, valid loss: 0.03332
# [Epoch 87] train loss: 0.02898, valid loss: 0.03980
# [Epoch 88] train loss: 0.03406, valid loss: 0.04069
# [Epoch 89] train loss: 0.03351, valid loss: 0.06107
# [Epoch 90] train loss: 0.02373, valid loss: 0.03062
# [Epoch 91] train loss: 0.01792, valid loss: 0.03346
# [Epoch 92] train loss: 0.01761, valid loss: 0.03370
# [Epoch 93] train loss: 0.02137, valid loss: 0.03138
# [Epoch 94] train loss: 0.01830, valid loss: 0.03347
# [Epoch 95] train loss: 0.01880, valid loss: 0.03178
# [Epoch 96] train loss: 0.02087, valid loss: 0.03095
# [Epoch 97] train loss: 0.01740, valid loss: 0.05445
# [Epoch 98] train loss: 0.02052, valid loss: 0.03526
# [Epoch 99] train loss: 0.02207, valid loss: 0.07034
# =======================================
#   Best epoch: 58, valid loss: 0.02772
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 3.46033, valid loss: 0.14290
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.12927, valid loss: 0.10880
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.12554, valid loss: 0.12337
# [Epoch 3] train loss: 0.10776, valid loss: 0.08859
# +++++ Saved as Best-Epoch: 3 ++++++
# [Epoch 4] train loss: 0.09649, valid loss: 0.08023
# +++++ Saved as Best-Epoch: 4 ++++++
# [Epoch 5] train loss: 0.08405, valid loss: 0.08070
# [Epoch 6] train loss: 0.08631, valid loss: 0.05698
# +++++ Saved as Best-Epoch: 6 ++++++
# [Epoch 7] train loss: 0.06444, valid loss: 0.05019
# +++++ Saved as Best-Epoch: 7 ++++++
# [Epoch 8] train loss: 0.04652, valid loss: 0.04477
# +++++ Saved as Best-Epoch: 8 ++++++
# [Epoch 9] train loss: 0.04394, valid loss: 0.07665
# [Epoch 10] train loss: 0.04693, valid loss: 0.05182
# [Epoch 11] train loss: 0.04546, valid loss: 0.06032
# [Epoch 12] train loss: 0.04023, valid loss: 0.03574
# +++++ Saved as Best-Epoch: 12 ++++++
# [Epoch 13] train loss: 0.03459, valid loss: 0.03201
# +++++ Saved as Best-Epoch: 13 ++++++
# [Epoch 14] train loss: 0.03687, valid loss: 0.03109
# +++++ Saved as Best-Epoch: 14 ++++++
# [Epoch 15] train loss: 0.04016, valid loss: 0.03703
# [Epoch 16] train loss: 0.03198, valid loss: 0.05115
# [Epoch 17] train loss: 0.04447, valid loss: 0.03881
# [Epoch 18] train loss: 0.04307, valid loss: 0.02812
# +++++ Saved as Best-Epoch: 18 ++++++
# [Epoch 19] train loss: 0.04547, valid loss: 0.02495
# +++++ Saved as Best-Epoch: 19 ++++++
# [Epoch 20] train loss: 0.03461, valid loss: 0.02359
# +++++ Saved as Best-Epoch: 20 ++++++
# [Epoch 21] train loss: 0.02534, valid loss: 0.01922
# +++++ Saved as Best-Epoch: 21 ++++++
# [Epoch 22] train loss: 0.02605, valid loss: 0.02215
# [Epoch 23] train loss: 0.02529, valid loss: 0.01964
# [Epoch 24] train loss: 0.02022, valid loss: 0.01991
# [Epoch 25] train loss: 0.01892, valid loss: 0.01397
# +++++ Saved as Best-Epoch: 25 ++++++
# [Epoch 26] train loss: 0.01738, valid loss: 0.01451
# [Epoch 27] train loss: 0.01654, valid loss: 0.01424
# [Epoch 28] train loss: 0.01706, valid loss: 0.01279
# +++++ Saved as Best-Epoch: 28 ++++++
# [Epoch 29] train loss: 0.01746, valid loss: 0.01645
# [Epoch 30] train loss: 0.01769, valid loss: 0.01253
# +++++ Saved as Best-Epoch: 30 ++++++
# [Epoch 31] train loss: 0.01697, valid loss: 0.01233
# +++++ Saved as Best-Epoch: 31 ++++++
# [Epoch 32] train loss: 0.01530, valid loss: 0.01261
# [Epoch 33] train loss: 0.01461, valid loss: 0.01202
# +++++ Saved as Best-Epoch: 33 ++++++
# [Epoch 34] train loss: 0.01429, valid loss: 0.01544
# [Epoch 35] train loss: 0.01560, valid loss: 0.01455
# [Epoch 36] train loss: 0.01288, valid loss: 0.01541
# [Epoch 37] train loss: 0.01378, valid loss: 0.01408
# [Epoch 38] train loss: 0.01317, valid loss: 0.01052
# +++++ Saved as Best-Epoch: 38 ++++++
# [Epoch 39] train loss: 0.01216, valid loss: 0.01122
# [Epoch 40] train loss: 0.01369, valid loss: 0.00937
# +++++ Saved as Best-Epoch: 40 ++++++
# [Epoch 41] train loss: 0.01357, valid loss: 0.01042
# [Epoch 42] train loss: 0.01180, valid loss: 0.01007
# [Epoch 43] train loss: 0.01066, valid loss: 0.01591
# [Epoch 44] train loss: 0.01840, valid loss: 0.01495
# [Epoch 45] train loss: 0.01528, valid loss: 0.01544
# [Epoch 46] train loss: 0.01187, valid loss: 0.01111
# [Epoch 47] train loss: 0.01051, valid loss: 0.01006
# [Epoch 48] train loss: 0.00984, valid loss: 0.00999
# [Epoch 49] train loss: 0.01227, valid loss: 0.01020
# [Epoch 50] train loss: 0.01097, valid loss: 0.00955
# [Epoch 51] train loss: 0.01044, valid loss: 0.01216
# [Epoch 52] train loss: 0.01127, valid loss: 0.00986
# [Epoch 53] train loss: 0.01317, valid loss: 0.01439
# [Epoch 54] train loss: 0.01446, valid loss: 0.01588
# [Epoch 55] train loss: 0.01299, valid loss: 0.01030
# [Epoch 56] train loss: 0.01078, valid loss: 0.01475
# [Epoch 57] train loss: 0.01112, valid loss: 0.01661
# [Epoch 58] train loss: 0.01150, valid loss: 0.00978
# [Epoch 59] train loss: 0.00913, valid loss: 0.00970
# [Epoch 60] train loss: 0.00965, valid loss: 0.01056
# [Epoch 61] train loss: 0.00939, valid loss: 0.00987
# [Epoch 62] train loss: 0.00971, valid loss: 0.01051
# [Epoch 63] train loss: 0.00908, valid loss: 0.01522
# [Epoch 64] train loss: 0.00994, valid loss: 0.01426
# [Epoch 65] train loss: 0.00854, valid loss: 0.01084
# [Epoch 66] train loss: 0.00895, valid loss: 0.01432
# [Epoch 67] train loss: 0.01348, valid loss: 0.01744
# [Epoch 68] train loss: 0.01052, valid loss: 0.01090
# [Epoch 69] train loss: 0.01089, valid loss: 0.01450
# [Epoch 70] train loss: 0.01141, valid loss: 0.01135
# [Epoch 71] train loss: 0.00892, valid loss: 0.01859
# [Epoch 72] train loss: 0.01274, valid loss: 0.01824
# [Epoch 73] train loss: 0.01037, valid loss: 0.01196
# [Epoch 74] train loss: 0.01193, valid loss: 0.01489
# [Epoch 75] train loss: 0.01109, valid loss: 0.01072
# [Epoch 76] train loss: 0.00796, valid loss: 0.01019
# [Epoch 77] train loss: 0.00783, valid loss: 0.01051
# [Epoch 78] train loss: 0.00757, valid loss: 0.01452
# [Epoch 79] train loss: 0.00976, valid loss: 0.01596
# [Epoch 80] train loss: 0.00858, valid loss: 0.01150
# [Epoch 81] train loss: 0.00755, valid loss: 0.01037
# [Epoch 82] train loss: 0.00757, valid loss: 0.01167
# [Epoch 83] train loss: 0.00749, valid loss: 0.01074
# [Epoch 84] train loss: 0.00755, valid loss: 0.01360
# [Epoch 85] train loss: 0.00708, valid loss: 0.01618
# [Epoch 86] train loss: 0.00844, valid loss: 0.01118
# [Epoch 87] train loss: 0.00659, valid loss: 0.01162
# [Epoch 88] train loss: 0.00610, valid loss: 0.01156
# [Epoch 89] train loss: 0.00675, valid loss: 0.01259
# [Epoch 90] train loss: 0.01019, valid loss: 0.01517
# [Epoch 91] train loss: 0.01013, valid loss: 0.02455
# [Epoch 92] train loss: 0.01012, valid loss: 0.01668
# [Epoch 93] train loss: 0.00828, valid loss: 0.01884
# [Epoch 94] train loss: 0.00792, valid loss: 0.01598
# [Epoch 95] train loss: 0.00784, valid loss: 0.01628
# [Epoch 96] train loss: 0.00715, valid loss: 0.01422
# [Epoch 97] train loss: 0.00954, valid loss: 0.01578
# [Epoch 98] train loss: 0.00771, valid loss: 0.01773
# [Epoch 99] train loss: 0.00759, valid loss: 0.01521
# =======================================
#   Best epoch: 40, valid loss: 0.00937
# =======================================

# %%
fig = plt.figure(figsize=(25, 5))
for i in range(num_splits):
    ax = fig.add_subplot(1, num_splits, i+1)
    ax.plot(history[i]["train"], label="train loss")
    ax.plot(history[i]["valid"], label="valid loss")
    ax.set_title(f"Fold {i}")
    ax.set_ylim([0.01, 1.1])
    ax.set_yscale("log")
    ax.legend()
plt.show()

# %%
sample_id_1 = 1
sample_id_2 = 9
plt.plot(pred_results[0]["true"][sample_id_1][0], label="true 1", color="C1")
plt.plot(pred_results[0]["pred"][sample_id_1][0], label="pred 1", color="orange")
plt.plot((pred_results[0]["pred"][sample_id_1][0] - 1) * -1, label="pred 1 reversed", ls="--", color="orange")


plt.plot(pred_results[0]["true"][sample_id_2][0], label="true 2", color="blue")
plt.plot(pred_results[0]["pred"][sample_id_2][0], label="pred 2", color="blue", alpha=0.3)
plt.plot((pred_results[0]["pred"][sample_id_2][0] - 1) * -1, label="pred 2 reversed", color="blue", ls="--", alpha=0.3)

plt.legend()

# %% [markdown]
# ## 学習データと予測値

# %%
sample_id_1 = 1

sample_x = train_x[sample_id_1, :, :].transpose(1, 0).reshape(1, 16, 1000)
sample_y = train_y[sample_id_1, :, 0]
plt.plot(sample_y, label="True")
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")
    model.to("cpu")
    pred_y = model(torch.tensor(sample_x, dtype=torch.float32)).detach().numpy()

    plt.plot(pred_y[0], label=f"Pred (Fold {i})", ls="--")

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_110606/828188601.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")

# %%
sample_id_1 = 8

sample_x = train_x[sample_id_1, :, :].transpose(1, 0).reshape(1, 16, 1000)
sample_y = train_y[sample_id_1, :, axis]
plt.plot(sample_y, label="True")
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")
    model.to("cpu")
    pred_y = model(torch.tensor(sample_x, dtype=torch.float32)).detach().numpy()

    plt.plot(pred_y[0], label=f"Pred (Fold {i})", ls="--")

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_110606/1007387240.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")

# %% [markdown]
# ## 評価データと予測値

# %%
from sklearn.metrics import mean_absolute_error

def show_test_pred(sample_id: int=0):
    sample_x = test_x[sample_id, :, :].transpose(1, 0).reshape(1, 16, 1000)
    sample_y = test_y[sample_id, :, axis]
    preds = []
    fig = plt.figure(figsize=(12, 5))
    plt.plot(sample_y, label="True", lw=2, color="black")
    for i in range(num_splits):
        model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
        model.to("cpu")
        pred_y = model(torch.tensor(sample_x, dtype=torch.float32)).detach().numpy()
        preds.append(pred_y[0])
        plt.plot(pred_y[0], label=f"Pred (Fold {i})", ls="--", color=f"C{i+1}")
        plt.plot((pred_y[0]-1)*-1, label=f"Pred (Fold {i}, reversed)", ls="-.", color=f"C{i+1}")
    
    mean_pred = (np.mean(preds, axis=0)) 
    pred_rev = (mean_pred-1)*-1
    plt.plot(mean_pred, label="Mean", color="Blue", lw=1.5)
    plt.plot(pred_rev, label="Mean (reversed)", color="Red", lw=1.5)

    mean_error = mean_absolute_error(sample_y, mean_pred)
    mean_rev_error = mean_absolute_error(sample_y, pred_rev)
    plt.legend()
    plt.title(f"Sample: {sample_id}, Mean: {mean_error:.5f}, Rev: {mean_rev_error:.5f}")
    plt.show()
    
    

for i in [0, 9, 318]:
    show_test_pred(i)
# Out:
# /tmp/ipykernel_110606/2305665677.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# /tmp/ipykernel_110606/2305665677.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# /tmp/ipykernel_110606/2305665677.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")

# %%
axis = 0
preds = []
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
    model.to(device)
    pred_in_fold = []
    with torch.no_grad():
        for x, y in zip(test_x, test_y):
            x = x.transpose(1, 0).reshape(1, 16, 1000)
            x = torch.tensor(x, dtype=torch.float32)
            x = x.to(device)
            pred = model(x)
            pred = pred.to("cpu")
            pred = pred.detach().numpy()
            pred_in_fold.append(pred)

    preds.append(np.array(pred_in_fold))

mean_pred = np.mean(preds, axis=0).reshape(-1, 30)
rev_pred = (mean_pred - 1) * -1
mean_loss = mean_absolute_error(test_y[:, :, axis], mean_pred)
rev_loss = mean_absolute_error(test_y[:, :, axis], rev_pred)

print(
f"""
Mean     : {mean_loss:.5f}
Reversed : {rev_loss:.5f} 
"""
)
# Out:
# /tmp/ipykernel_110606/3545400414.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# Mean     : 0.38048
# Reversed : 0.26799

# %%
axis = 1
preds = []
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
    model.to(device)
    pred_in_fold = []
    with torch.no_grad():
        for x, y in zip(test_x, test_y):
            x = x.transpose(1, 0).reshape(1, 16, 1000)
            x = torch.tensor(x, dtype=torch.float32)
            x = x.to(device)
            pred = model(x)
            pred = pred.to("cpu")
            pred = pred.detach().numpy()
            pred_in_fold.append(pred)

    preds.append(np.array(pred_in_fold))

mean_pred = np.mean(preds, axis=0).reshape(-1, 30)
rev_pred = (mean_pred - 1) * -1
mean_loss = mean_absolute_error(test_y[:, :, axis], mean_pred)
rev_loss = mean_absolute_error(test_y[:, :, axis], rev_pred)

print(
f"""
Mean     : {mean_loss:.5f}
Reversed : {rev_loss:.5f} 
"""
)
# Out:
# /tmp/ipykernel_110606/1523580880.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# Mean     : 0.22193
# Reversed : 0.14286

# %%
axis = 2
preds = []
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
    model.to(device)
    pred_in_fold = []
    with torch.no_grad():
        for x, y in zip(test_x, test_y):
            x = x.transpose(1, 0).reshape(1, 16, 1000)
            x = torch.tensor(x, dtype=torch.float32)
            x = x.to(device)
            pred = model(x)
            pred = pred.to("cpu")
            pred = pred.detach().numpy()
            pred_in_fold.append(pred)

    preds.append(np.array(pred_in_fold))

mean_pred = np.mean(preds, axis=0).reshape(-1, 30)
rev_pred = (mean_pred - 1) * -1
mean_loss = mean_absolute_error(test_y[:, :, axis], mean_pred)
rev_loss = mean_absolute_error(test_y[:, :, axis], rev_pred)

print(
f"""
Mean     : {mean_loss:.5f}
Reversed : {rev_loss:.5f} 
"""
)
# Out:
# /tmp/ipykernel_110606/3322386290.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# Mean     : 0.21184
# Reversed : 0.21432
