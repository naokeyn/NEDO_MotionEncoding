# %%
import os, json
from tqdm.notebook import tqdm
import numpy as np
import matplotlib.pyplot as plt

import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader

import scipy.io as sio
from sklearn.model_selection import KFold

# %%
import sys
sys.path.append("..")
from src.preprocess import EmgEncoder

# %% [markdown]
# ## データの前処理

# %%
reference = sio.loadmat("../data/reference.mat")

train_encoder = EmgEncoder()
train_x = reference["0005"][0][0][0]
train_y = reference["0005"][0][0][1]
test_x = reference["0005"][0][0][2]
test_y = reference["0005"][0][0][3]

train_x = train_encoder.fit_transform(train_x)
y_scaler = [train_y.max(), train_y.min()]
train_y = (train_y - y_scaler[1]) / (y_scaler[0] - y_scaler[1])
train_y = train_y.transpose(0, 2, 1)

test_x = train_encoder.transform(test_x)
test_y = (test_y - y_scaler[1]) / (y_scaler[0] - y_scaler[1])
test_y = test_y.transpose(0, 2, 1)

train_x.shape, test_x.shape, train_y.shape, test_y.shape
# Out:
# ((320, 1000, 16), (320, 1000, 16), (320, 30, 3), (320, 30, 3))

# %% [markdown]
# ## モデルの定義

# %%
def compile_model(dropout: float=0.1, learning_rate: float=10e-3):
    model = nn.Sequential(
        nn.Flatten(),
        nn.Linear(16000, 32000, dtype=torch.float32),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(32000, 1000, dtype=torch.float32),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(1000, 500, dtype=torch.float32),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(500, 100, dtype=torch.float32),
        nn.Dropout(dropout),
        # nn.ReLU(),
        nn.Tanh(),
        nn.Linear(100, 30, dtype=torch.float32)
    )   
    loss_function = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    return model, optimizer, loss_function

def compile_model2(dropout: float=0.2, learning_rate: float=10e-3):
    model = nn.Sequential(
        nn.Conv1d(in_channels=16, out_channels=64, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.ReLU(),
        nn.AdaptiveMaxPool1d(30),
        nn.Flatten(start_dim=1),
        nn.Linear(128*30, 30),
    )
    loss_function = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    return model, optimizer, loss_function

def compile_model3(dropout: float=0.2, learning_rate: float=10e-3):
    model = nn.Sequential(
        # Conv1D層1: 入力チャンネル16 -> 出力チャンネル64
        nn.Conv1d(in_channels=16, out_channels=64, kernel_size=3, padding=1),
        nn.BatchNorm1d(64),  # バッチ正規化
        nn.ReLU(),
        
        # Conv1D層2: 入力チャンネル64 -> 出力チャンネル128
        nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
        nn.BatchNorm1d(128),  # バッチ正規化
        nn.ReLU(),
        
        # Conv1D層3: 入力チャンネル128 -> 出力チャンネル256
        nn.Conv1d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
        nn.BatchNorm1d(256),  # バッチ正規化
        nn.ReLU(),
        
        # プーリング層で時系列を30に縮小
        nn.AdaptiveMaxPool1d(30),
        
        nn.Flatten(start_dim=1),
        
        # 全結合層1: 入力256 * 30 -> 隠れ層512
        nn.Linear(256 * 30, 512),
        nn.Tanh(),
        nn.Dropout(dropout),        
        nn.Linear(512, 30)
    )

    # 損失関数と最適化関数
    loss_function = nn.MSELoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    
    return model, optimizer, loss_function

def train_1epoch(model, loss_fn, optimizer, train_loader):
    total_loss = 0
    for i, (x, y) in enumerate(train_loader):
        x = x.to(device)
        y = y.to(device)
        optimizer.zero_grad()
        pred = model(x)
        loss = loss_fn(pred, y)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    
    return total_loss / len(train_loader)

def valid_1epoch(model, loss_fn, valid_loader):
    total_loss = 0
    with torch.no_grad():
        for i, (x, y) in enumerate(valid_loader):
            x = x.to(device)
            y = y.to(device)
            pred = model(x)
            total_loss += loss_fn(pred, y).item()
        
    return total_loss / len(valid_loader)

def predict(model, test_loader):
    results = {"true": [], "pred": []}
    with torch.no_grad():
        for i, (x, y) in enumerate(test_loader):
            x = x.to(device)
            y = y.to(device)
            pred = model(x)

            results["true"].append(y.to("cpu"))
            results["pred"].append(pred.to("cpu"))
    return results

# %% [markdown]
# ## Datasetの作成

# %%
class RefDataset(torch.utils.data.Dataset):
    def __init__(self, x, y, y_axis: int=0):
        super().__init__()
        self.x = x
        self.y = y
        self.y_axis = y_axis
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x = torch.tensor(self.x[idx, :, :].transpose(1, 0), dtype=torch.float32)
        y = torch.tensor(self.y[idx, :, self.y_axis], dtype=torch.float32)
        
        return x, y

# %% [markdown]
# ## KFold CV

# %%
batch_size = 30
dropout = 0.3
epochs = 100
hidden_state = [32000, 1000, 500, 100]
learning_rate = 10e-3
num_layers = 4
num_splits = 5
num_workers = 12

axis = 2

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

dataset = RefDataset(train_x, train_y, y_axis=0)
test_dataset = RefDataset(test_x, test_y, y_axis=axis)

pred_results = []
history = []
kf = KFold(n_splits=num_splits, shuffle=True, random_state=42)
for i, (train_idx, valid_idx) in enumerate(kf.split(range(len(dataset)))):
    train_dataset = torch.utils.data.Subset(dataset, train_idx)
    valid_dataset = torch.utils.data.Subset(dataset, valid_idx)
    
    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        shuffle=True
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        shuffle=False
    )
    test_loader = torch.utils.data.DataLoader(
        test_dataset,
        batch_size=1,
        num_workers=num_workers,
        shuffle=False
    )
    
    # model, optimizer, loss_fn = compile_model(dropout=dropout, num_layer=num_layers, hidden_state=hidden_state)
    model, optimizer, loss_fn = compile_model2(dropout=dropout, learning_rate=learning_rate)
    # model, optimizer, loss_fn = compile_model3(dropout=dropout)
    
    model.to(device)
    history_1epoch = {"train": [], "valid": []}
    best_value = 10e9
    best_epoch = 0
    for epoch in tqdm(range(epochs)):
        model.train()
        train_loss = train_1epoch(model, loss_fn, optimizer, train_loader)
        model.eval()
        valid_loss = valid_1epoch(model, loss_fn, valid_loader)
        print(f"[Epoch {epoch}] train loss: {train_loss:.5f}, valid loss: {valid_loss:.5f}")
        history_1epoch["train"].append(train_loss)
        history_1epoch["valid"].append(valid_loss)
        
        if valid_loss < best_value:
            print(f"+++++ Saved as Best-Epoch: {epoch} ++++++")
            torch.save(model, f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
            best_value = valid_loss
            best_epoch = epoch
            
        
    results = predict(model, test_loader)
    pred_results.append(results)
    history.append(history_1epoch)
    
    torch.save(model, f"../models/Fold{i}_Axis{axis}_FinalEpoch.pt")
    print("=======================================")
    print(f"  Best epoch: {best_epoch}, valid loss: {best_value:.5f}")
    print("=======================================")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 1.21175, valid loss: 0.38659
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.24424, valid loss: 0.15668
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.11131, valid loss: 0.13195
# +++++ Saved as Best-Epoch: 2 ++++++
# [Epoch 3] train loss: 0.09813, valid loss: 0.10462
# +++++ Saved as Best-Epoch: 3 ++++++
# [Epoch 4] train loss: 0.09522, valid loss: 0.10602
# [Epoch 5] train loss: 0.08981, valid loss: 0.10344
# +++++ Saved as Best-Epoch: 5 ++++++
# [Epoch 6] train loss: 0.09259, valid loss: 0.10444
# [Epoch 7] train loss: 0.09090, valid loss: 0.10338
# +++++ Saved as Best-Epoch: 7 ++++++
# [Epoch 8] train loss: 0.09172, valid loss: 0.09674
# +++++ Saved as Best-Epoch: 8 ++++++
# [Epoch 9] train loss: 0.08321, valid loss: 0.09101
# +++++ Saved as Best-Epoch: 9 ++++++
# [Epoch 10] train loss: 0.07363, valid loss: 0.07722
# +++++ Saved as Best-Epoch: 10 ++++++
# [Epoch 11] train loss: 0.06754, valid loss: 0.06331
# +++++ Saved as Best-Epoch: 11 ++++++
# [Epoch 12] train loss: 0.05388, valid loss: 0.05260
# +++++ Saved as Best-Epoch: 12 ++++++
# [Epoch 13] train loss: 0.06108, valid loss: 0.07726
# [Epoch 14] train loss: 0.05367, valid loss: 0.06256
# [Epoch 15] train loss: 0.05146, valid loss: 0.07748
# [Epoch 16] train loss: 0.04854, valid loss: 0.04133
# +++++ Saved as Best-Epoch: 16 ++++++
# [Epoch 17] train loss: 0.04402, valid loss: 0.03903
# +++++ Saved as Best-Epoch: 17 ++++++
# [Epoch 18] train loss: 0.04484, valid loss: 0.06442
# [Epoch 19] train loss: 0.05453, valid loss: 0.04317
# [Epoch 20] train loss: 0.04869, valid loss: 0.03929
# [Epoch 21] train loss: 0.03800, valid loss: 0.04549
# [Epoch 22] train loss: 0.03422, valid loss: 0.03456
# +++++ Saved as Best-Epoch: 22 ++++++
# [Epoch 23] train loss: 0.03208, valid loss: 0.04541
# [Epoch 24] train loss: 0.03732, valid loss: 0.03496
# [Epoch 25] train loss: 0.04537, valid loss: 0.03712
# [Epoch 26] train loss: 0.04966, valid loss: 0.08769
# [Epoch 27] train loss: 0.04309, valid loss: 0.05779
# [Epoch 28] train loss: 0.03342, valid loss: 0.04349
# [Epoch 29] train loss: 0.03582, valid loss: 0.03089
# +++++ Saved as Best-Epoch: 29 ++++++
# [Epoch 30] train loss: 0.03706, valid loss: 0.03476
# [Epoch 31] train loss: 0.03286, valid loss: 0.04568
# [Epoch 32] train loss: 0.02973, valid loss: 0.02852
# +++++ Saved as Best-Epoch: 32 ++++++
# [Epoch 33] train loss: 0.02614, valid loss: 0.02844
# +++++ Saved as Best-Epoch: 33 ++++++
# [Epoch 34] train loss: 0.02521, valid loss: 0.02737
# +++++ Saved as Best-Epoch: 34 ++++++
# [Epoch 35] train loss: 0.02690, valid loss: 0.02905
# [Epoch 36] train loss: 0.02366, valid loss: 0.03497
# [Epoch 37] train loss: 0.03395, valid loss: 0.03717
# [Epoch 38] train loss: 0.02763, valid loss: 0.02832
# [Epoch 39] train loss: 0.03022, valid loss: 0.03238
# [Epoch 40] train loss: 0.02888, valid loss: 0.04193
# [Epoch 41] train loss: 0.03313, valid loss: 0.04049
# [Epoch 42] train loss: 0.04457, valid loss: 0.02760
# [Epoch 43] train loss: 0.03765, valid loss: 0.02720
# +++++ Saved as Best-Epoch: 43 ++++++
# [Epoch 44] train loss: 0.02703, valid loss: 0.04916
# [Epoch 45] train loss: 0.03027, valid loss: 0.02857
# [Epoch 46] train loss: 0.02863, valid loss: 0.03013
# [Epoch 47] train loss: 0.02283, valid loss: 0.02604
# +++++ Saved as Best-Epoch: 47 ++++++
# [Epoch 48] train loss: 0.02185, valid loss: 0.03064
# [Epoch 49] train loss: 0.02152, valid loss: 0.03196
# [Epoch 50] train loss: 0.02290, valid loss: 0.03217
# [Epoch 51] train loss: 0.02962, valid loss: 0.03139
# [Epoch 52] train loss: 0.02180, valid loss: 0.03074
# [Epoch 53] train loss: 0.02235, valid loss: 0.03157
# [Epoch 54] train loss: 0.02398, valid loss: 0.03272
# [Epoch 55] train loss: 0.02495, valid loss: 0.02713
# [Epoch 56] train loss: 0.02165, valid loss: 0.02641
# [Epoch 57] train loss: 0.02297, valid loss: 0.03354
# [Epoch 58] train loss: 0.02214, valid loss: 0.03289
# [Epoch 59] train loss: 0.01999, valid loss: 0.03545
# [Epoch 60] train loss: 0.02179, valid loss: 0.02771
# [Epoch 61] train loss: 0.02196, valid loss: 0.02735
# [Epoch 62] train loss: 0.02614, valid loss: 0.03778
# [Epoch 63] train loss: 0.02567, valid loss: 0.05048
# [Epoch 64] train loss: 0.02254, valid loss: 0.03030
# [Epoch 65] train loss: 0.02286, valid loss: 0.03479
# [Epoch 66] train loss: 0.02295, valid loss: 0.02715
# [Epoch 67] train loss: 0.02346, valid loss: 0.05125
# [Epoch 68] train loss: 0.03873, valid loss: 0.04357
# [Epoch 69] train loss: 0.03111, valid loss: 0.06104
# [Epoch 70] train loss: 0.02687, valid loss: 0.02740
# [Epoch 71] train loss: 0.02392, valid loss: 0.03338
# [Epoch 72] train loss: 0.02016, valid loss: 0.02730
# [Epoch 73] train loss: 0.01995, valid loss: 0.02866
# [Epoch 74] train loss: 0.02235, valid loss: 0.03017
# [Epoch 75] train loss: 0.02732, valid loss: 0.02823
# [Epoch 76] train loss: 0.02698, valid loss: 0.02886
# [Epoch 77] train loss: 0.01991, valid loss: 0.03067
# [Epoch 78] train loss: 0.01895, valid loss: 0.03306
# [Epoch 79] train loss: 0.01861, valid loss: 0.02920
# [Epoch 80] train loss: 0.01897, valid loss: 0.02680
# [Epoch 81] train loss: 0.01970, valid loss: 0.02731
# [Epoch 82] train loss: 0.02401, valid loss: 0.04074
# [Epoch 83] train loss: 0.02123, valid loss: 0.02801
# [Epoch 84] train loss: 0.01915, valid loss: 0.03530
# [Epoch 85] train loss: 0.01852, valid loss: 0.02738
# [Epoch 86] train loss: 0.02074, valid loss: 0.02780
# [Epoch 87] train loss: 0.01815, valid loss: 0.03122
# [Epoch 88] train loss: 0.01857, valid loss: 0.03493
# [Epoch 89] train loss: 0.01837, valid loss: 0.03060
# [Epoch 90] train loss: 0.01995, valid loss: 0.03227
# [Epoch 91] train loss: 0.01934, valid loss: 0.03396
# [Epoch 92] train loss: 0.02846, valid loss: 0.02893
# [Epoch 93] train loss: 0.01852, valid loss: 0.03118
# [Epoch 94] train loss: 0.02173, valid loss: 0.03514
# [Epoch 95] train loss: 0.02183, valid loss: 0.04478
# [Epoch 96] train loss: 0.02274, valid loss: 0.02960
# [Epoch 97] train loss: 0.01995, valid loss: 0.03247
# [Epoch 98] train loss: 0.01978, valid loss: 0.03792
# [Epoch 99] train loss: 0.01770, valid loss: 0.03197
# =======================================
#   Best epoch: 47, valid loss: 0.02604
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 3.95854, valid loss: 0.21084
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.17815, valid loss: 0.09223
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.11168, valid loss: 0.08001
# +++++ Saved as Best-Epoch: 2 ++++++
# [Epoch 3] train loss: 0.09776, valid loss: 0.07415
# +++++ Saved as Best-Epoch: 3 ++++++
# [Epoch 4] train loss: 0.08752, valid loss: 0.06169
# +++++ Saved as Best-Epoch: 4 ++++++
# [Epoch 5] train loss: 0.06688, valid loss: 0.05118
# +++++ Saved as Best-Epoch: 5 ++++++
# [Epoch 6] train loss: 0.06381, valid loss: 0.05619
# [Epoch 7] train loss: 0.06563, valid loss: 0.07887
# [Epoch 8] train loss: 0.05747, valid loss: 0.04126
# +++++ Saved as Best-Epoch: 8 ++++++
# [Epoch 9] train loss: 0.05381, valid loss: 0.03299
# +++++ Saved as Best-Epoch: 9 ++++++
# [Epoch 10] train loss: 0.04270, valid loss: 0.03674
# [Epoch 11] train loss: 0.03855, valid loss: 0.02220
# +++++ Saved as Best-Epoch: 11 ++++++
# [Epoch 12] train loss: 0.03650, valid loss: 0.02000
# +++++ Saved as Best-Epoch: 12 ++++++
# [Epoch 13] train loss: 0.03195, valid loss: 0.01958
# +++++ Saved as Best-Epoch: 13 ++++++
# [Epoch 14] train loss: 0.03909, valid loss: 0.04061
# [Epoch 15] train loss: 0.04181, valid loss: 0.02226
# [Epoch 16] train loss: 0.03559, valid loss: 0.01991
# [Epoch 17] train loss: 0.03205, valid loss: 0.03803
# [Epoch 18] train loss: 0.03536, valid loss: 0.05143
# [Epoch 19] train loss: 0.03607, valid loss: 0.03822
# [Epoch 20] train loss: 0.03328, valid loss: 0.02283
# [Epoch 21] train loss: 0.02808, valid loss: 0.04299
# [Epoch 22] train loss: 0.03664, valid loss: 0.02772
# [Epoch 23] train loss: 0.03088, valid loss: 0.02248
# [Epoch 24] train loss: 0.03130, valid loss: 0.06364
# [Epoch 25] train loss: 0.03520, valid loss: 0.02825
# [Epoch 26] train loss: 0.02992, valid loss: 0.01854
# +++++ Saved as Best-Epoch: 26 ++++++
# [Epoch 27] train loss: 0.01864, valid loss: 0.03782
# [Epoch 28] train loss: 0.02635, valid loss: 0.01574
# +++++ Saved as Best-Epoch: 28 ++++++
# [Epoch 29] train loss: 0.02044, valid loss: 0.01815
# [Epoch 30] train loss: 0.01530, valid loss: 0.01540
# +++++ Saved as Best-Epoch: 30 ++++++
# [Epoch 31] train loss: 0.01653, valid loss: 0.02652
# [Epoch 32] train loss: 0.02387, valid loss: 0.01894
# [Epoch 33] train loss: 0.02279, valid loss: 0.01714
# [Epoch 34] train loss: 0.01342, valid loss: 0.01660
# [Epoch 35] train loss: 0.01407, valid loss: 0.01559
# [Epoch 36] train loss: 0.01243, valid loss: 0.01413
# +++++ Saved as Best-Epoch: 36 ++++++
# [Epoch 37] train loss: 0.01455, valid loss: 0.01939
# [Epoch 38] train loss: 0.01221, valid loss: 0.01749
# [Epoch 39] train loss: 0.01230, valid loss: 0.01957
# [Epoch 40] train loss: 0.01213, valid loss: 0.01530
# [Epoch 41] train loss: 0.01185, valid loss: 0.01507
# [Epoch 42] train loss: 0.01139, valid loss: 0.02001
# [Epoch 43] train loss: 0.01160, valid loss: 0.01541
# [Epoch 44] train loss: 0.01243, valid loss: 0.01417
# [Epoch 45] train loss: 0.01333, valid loss: 0.02107
# [Epoch 46] train loss: 0.01314, valid loss: 0.01774
# [Epoch 47] train loss: 0.01270, valid loss: 0.01448
# [Epoch 48] train loss: 0.01035, valid loss: 0.01577
# [Epoch 49] train loss: 0.01066, valid loss: 0.02236
# [Epoch 50] train loss: 0.01021, valid loss: 0.01459
# [Epoch 51] train loss: 0.01359, valid loss: 0.01668
# [Epoch 52] train loss: 0.01042, valid loss: 0.01643
# [Epoch 53] train loss: 0.00886, valid loss: 0.01424
# [Epoch 54] train loss: 0.00987, valid loss: 0.02720
# [Epoch 55] train loss: 0.01060, valid loss: 0.01534
# [Epoch 56] train loss: 0.01010, valid loss: 0.01616
# [Epoch 57] train loss: 0.00938, valid loss: 0.01468
# [Epoch 58] train loss: 0.00938, valid loss: 0.01481
# [Epoch 59] train loss: 0.01109, valid loss: 0.01676
# [Epoch 60] train loss: 0.01422, valid loss: 0.02941
# [Epoch 61] train loss: 0.01137, valid loss: 0.01756
# [Epoch 62] train loss: 0.01032, valid loss: 0.01557
# [Epoch 63] train loss: 0.01223, valid loss: 0.01482
# [Epoch 64] train loss: 0.01044, valid loss: 0.01743
# [Epoch 65] train loss: 0.01111, valid loss: 0.01897
# [Epoch 66] train loss: 0.01232, valid loss: 0.01499
# [Epoch 67] train loss: 0.01190, valid loss: 0.01526
# [Epoch 68] train loss: 0.00826, valid loss: 0.01733
# [Epoch 69] train loss: 0.01036, valid loss: 0.01472
# [Epoch 70] train loss: 0.01119, valid loss: 0.01480
# [Epoch 71] train loss: 0.00985, valid loss: 0.01888
# [Epoch 72] train loss: 0.00888, valid loss: 0.01597
# [Epoch 73] train loss: 0.00954, valid loss: 0.02442
# [Epoch 74] train loss: 0.00923, valid loss: 0.01537
# [Epoch 75] train loss: 0.00740, valid loss: 0.01463
# [Epoch 76] train loss: 0.00762, valid loss: 0.01668
# [Epoch 77] train loss: 0.00749, valid loss: 0.01505
# [Epoch 78] train loss: 0.00727, valid loss: 0.02477
# [Epoch 79] train loss: 0.00863, valid loss: 0.01579
# [Epoch 80] train loss: 0.00823, valid loss: 0.01524
# [Epoch 81] train loss: 0.00750, valid loss: 0.01697
# [Epoch 82] train loss: 0.00726, valid loss: 0.02042
# [Epoch 83] train loss: 0.01094, valid loss: 0.01512
# [Epoch 84] train loss: 0.01369, valid loss: 0.02537
# [Epoch 85] train loss: 0.01118, valid loss: 0.02030
# [Epoch 86] train loss: 0.00862, valid loss: 0.01539
# [Epoch 87] train loss: 0.00704, valid loss: 0.01595
# [Epoch 88] train loss: 0.00639, valid loss: 0.01613
# [Epoch 89] train loss: 0.00761, valid loss: 0.01555
# [Epoch 90] train loss: 0.00639, valid loss: 0.01592
# [Epoch 91] train loss: 0.00666, valid loss: 0.01624
# [Epoch 92] train loss: 0.00726, valid loss: 0.01850
# [Epoch 93] train loss: 0.00982, valid loss: 0.01883
# [Epoch 94] train loss: 0.01271, valid loss: 0.01765
# [Epoch 95] train loss: 0.01103, valid loss: 0.01660
# [Epoch 96] train loss: 0.00761, valid loss: 0.01543
# [Epoch 97] train loss: 0.00756, valid loss: 0.01952
# [Epoch 98] train loss: 0.00915, valid loss: 0.01668
# [Epoch 99] train loss: 0.01088, valid loss: 0.01769
# =======================================
#   Best epoch: 36, valid loss: 0.01413
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 3.42757, valid loss: 0.23769
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.16688, valid loss: 0.10602
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.10880, valid loss: 0.08785
# +++++ Saved as Best-Epoch: 2 ++++++
# [Epoch 3] train loss: 0.10192, valid loss: 0.08696
# +++++ Saved as Best-Epoch: 3 ++++++
# [Epoch 4] train loss: 0.09764, valid loss: 0.12658
# [Epoch 5] train loss: 0.10280, valid loss: 0.08404
# +++++ Saved as Best-Epoch: 5 ++++++
# [Epoch 6] train loss: 0.09569, valid loss: 0.06944
# +++++ Saved as Best-Epoch: 6 ++++++
# [Epoch 7] train loss: 0.08916, valid loss: 0.06547
# +++++ Saved as Best-Epoch: 7 ++++++
# [Epoch 8] train loss: 0.07889, valid loss: 0.06810
# [Epoch 9] train loss: 0.07566, valid loss: 0.12643
# [Epoch 10] train loss: 0.06667, valid loss: 0.04433
# +++++ Saved as Best-Epoch: 10 ++++++
# [Epoch 11] train loss: 0.08046, valid loss: 0.05181
# [Epoch 12] train loss: 0.07248, valid loss: 0.10224
# [Epoch 13] train loss: 0.07745, valid loss: 0.07583
# [Epoch 14] train loss: 0.05874, valid loss: 0.06690
# [Epoch 15] train loss: 0.04858, valid loss: 0.04433
# +++++ Saved as Best-Epoch: 15 ++++++
# [Epoch 16] train loss: 0.04140, valid loss: 0.03237
# +++++ Saved as Best-Epoch: 16 ++++++
# [Epoch 17] train loss: 0.03585, valid loss: 0.04104
# [Epoch 18] train loss: 0.04218, valid loss: 0.03923
# [Epoch 19] train loss: 0.04358, valid loss: 0.02882
# +++++ Saved as Best-Epoch: 19 ++++++
# [Epoch 20] train loss: 0.03873, valid loss: 0.03398
# [Epoch 21] train loss: 0.03565, valid loss: 0.04492
# [Epoch 22] train loss: 0.05256, valid loss: 0.05837
# [Epoch 23] train loss: 0.03611, valid loss: 0.02777
# +++++ Saved as Best-Epoch: 23 ++++++
# [Epoch 24] train loss: 0.04365, valid loss: 0.04739
# [Epoch 25] train loss: 0.03674, valid loss: 0.03417
# [Epoch 26] train loss: 0.03627, valid loss: 0.03215
# [Epoch 27] train loss: 0.03334, valid loss: 0.02877
# [Epoch 28] train loss: 0.02966, valid loss: 0.02626
# +++++ Saved as Best-Epoch: 28 ++++++
# [Epoch 29] train loss: 0.03553, valid loss: 0.02780
# [Epoch 30] train loss: 0.04005, valid loss: 0.02574
# +++++ Saved as Best-Epoch: 30 ++++++
# [Epoch 31] train loss: 0.03341, valid loss: 0.04711
# [Epoch 32] train loss: 0.05440, valid loss: 0.03952
# [Epoch 33] train loss: 0.03914, valid loss: 0.02672
# [Epoch 34] train loss: 0.03357, valid loss: 0.03070
# [Epoch 35] train loss: 0.02849, valid loss: 0.03350
# [Epoch 36] train loss: 0.03123, valid loss: 0.02377
# +++++ Saved as Best-Epoch: 36 ++++++
# [Epoch 37] train loss: 0.03464, valid loss: 0.02289
# +++++ Saved as Best-Epoch: 37 ++++++
# [Epoch 38] train loss: 0.02773, valid loss: 0.02533
# [Epoch 39] train loss: 0.02553, valid loss: 0.02219
# +++++ Saved as Best-Epoch: 39 ++++++
# [Epoch 40] train loss: 0.02410, valid loss: 0.03397
# [Epoch 41] train loss: 0.02618, valid loss: 0.03442
# [Epoch 42] train loss: 0.02995, valid loss: 0.02435
# [Epoch 43] train loss: 0.02657, valid loss: 0.02226
# [Epoch 44] train loss: 0.02453, valid loss: 0.02768
# [Epoch 45] train loss: 0.02839, valid loss: 0.02360
# [Epoch 46] train loss: 0.02385, valid loss: 0.03614
# [Epoch 47] train loss: 0.03263, valid loss: 0.02155
# +++++ Saved as Best-Epoch: 47 ++++++
# [Epoch 48] train loss: 0.03581, valid loss: 0.03623
# [Epoch 49] train loss: 0.03229, valid loss: 0.03796
# [Epoch 50] train loss: 0.02349, valid loss: 0.02411
# [Epoch 51] train loss: 0.02263, valid loss: 0.02173
# [Epoch 52] train loss: 0.02194, valid loss: 0.02315
# [Epoch 53] train loss: 0.02033, valid loss: 0.02443
# [Epoch 54] train loss: 0.02145, valid loss: 0.02213
# [Epoch 55] train loss: 0.02022, valid loss: 0.02143
# +++++ Saved as Best-Epoch: 55 ++++++
# [Epoch 56] train loss: 0.01970, valid loss: 0.02152
# [Epoch 57] train loss: 0.02213, valid loss: 0.02384
# [Epoch 58] train loss: 0.02850, valid loss: 0.02402
# [Epoch 59] train loss: 0.02344, valid loss: 0.02306
# [Epoch 60] train loss: 0.02933, valid loss: 0.05725
# [Epoch 61] train loss: 0.03400, valid loss: 0.02251
# [Epoch 62] train loss: 0.01935, valid loss: 0.02247
# [Epoch 63] train loss: 0.01872, valid loss: 0.02138
# +++++ Saved as Best-Epoch: 63 ++++++
# [Epoch 64] train loss: 0.01987, valid loss: 0.02604
# [Epoch 65] train loss: 0.02097, valid loss: 0.02658
# [Epoch 66] train loss: 0.02030, valid loss: 0.02627
# [Epoch 67] train loss: 0.01801, valid loss: 0.02246
# [Epoch 68] train loss: 0.01809, valid loss: 0.02959
# [Epoch 69] train loss: 0.02034, valid loss: 0.02398
# [Epoch 70] train loss: 0.01758, valid loss: 0.02383
# [Epoch 71] train loss: 0.01944, valid loss: 0.03021
# [Epoch 72] train loss: 0.01959, valid loss: 0.02632
# [Epoch 73] train loss: 0.02166, valid loss: 0.05684
# [Epoch 74] train loss: 0.02487, valid loss: 0.04559
# [Epoch 75] train loss: 0.03014, valid loss: 0.02584
# [Epoch 76] train loss: 0.02239, valid loss: 0.03995
# [Epoch 77] train loss: 0.02406, valid loss: 0.03739
# [Epoch 78] train loss: 0.02333, valid loss: 0.02413
# [Epoch 79] train loss: 0.01957, valid loss: 0.03195
# [Epoch 80] train loss: 0.01895, valid loss: 0.02355
# [Epoch 81] train loss: 0.01773, valid loss: 0.03656
# [Epoch 82] train loss: 0.02356, valid loss: 0.02668
# [Epoch 83] train loss: 0.02374, valid loss: 0.03492
# [Epoch 84] train loss: 0.01984, valid loss: 0.03649
# [Epoch 85] train loss: 0.02031, valid loss: 0.02982
# [Epoch 86] train loss: 0.02503, valid loss: 0.05937
# [Epoch 87] train loss: 0.03925, valid loss: 0.03752
# [Epoch 88] train loss: 0.04240, valid loss: 0.04432
# [Epoch 89] train loss: 0.02448, valid loss: 0.03045
# [Epoch 90] train loss: 0.02100, valid loss: 0.02572
# [Epoch 91] train loss: 0.01811, valid loss: 0.03658
# [Epoch 92] train loss: 0.01929, valid loss: 0.03791
# [Epoch 93] train loss: 0.02195, valid loss: 0.07144
# [Epoch 94] train loss: 0.03358, valid loss: 0.05782
# [Epoch 95] train loss: 0.03154, valid loss: 0.04050
# [Epoch 96] train loss: 0.03556, valid loss: 0.03601
# [Epoch 97] train loss: 0.02055, valid loss: 0.02809
# [Epoch 98] train loss: 0.01969, valid loss: 0.04287
# [Epoch 99] train loss: 0.01803, valid loss: 0.04271
# =======================================
#   Best epoch: 63, valid loss: 0.02138
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 2.64130, valid loss: 0.13242
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.18187, valid loss: 0.11567
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.12233, valid loss: 0.13628
# [Epoch 3] train loss: 0.11555, valid loss: 0.08582
# +++++ Saved as Best-Epoch: 3 ++++++
# [Epoch 4] train loss: 0.10556, valid loss: 0.08657
# [Epoch 5] train loss: 0.10409, valid loss: 0.10287
# [Epoch 6] train loss: 0.10000, valid loss: 0.08108
# +++++ Saved as Best-Epoch: 6 ++++++
# [Epoch 7] train loss: 0.07972, valid loss: 0.07454
# +++++ Saved as Best-Epoch: 7 ++++++
# [Epoch 8] train loss: 0.07794, valid loss: 0.06394
# +++++ Saved as Best-Epoch: 8 ++++++
# [Epoch 9] train loss: 0.06124, valid loss: 0.05997
# +++++ Saved as Best-Epoch: 9 ++++++
# [Epoch 10] train loss: 0.06056, valid loss: 0.05125
# +++++ Saved as Best-Epoch: 10 ++++++
# [Epoch 11] train loss: 0.05856, valid loss: 0.05309
# [Epoch 12] train loss: 0.05469, valid loss: 0.05850
# [Epoch 13] train loss: 0.04818, valid loss: 0.04425
# +++++ Saved as Best-Epoch: 13 ++++++
# [Epoch 14] train loss: 0.04501, valid loss: 0.04463
# [Epoch 15] train loss: 0.04527, valid loss: 0.04340
# +++++ Saved as Best-Epoch: 15 ++++++
# [Epoch 16] train loss: 0.04699, valid loss: 0.04019
# +++++ Saved as Best-Epoch: 16 ++++++
# [Epoch 17] train loss: 0.05060, valid loss: 0.06088
# [Epoch 18] train loss: 0.04702, valid loss: 0.05840
# [Epoch 19] train loss: 0.04162, valid loss: 0.05093
# [Epoch 20] train loss: 0.04127, valid loss: 0.04132
# [Epoch 21] train loss: 0.03628, valid loss: 0.03627
# +++++ Saved as Best-Epoch: 21 ++++++
# [Epoch 22] train loss: 0.03480, valid loss: 0.03778
# [Epoch 23] train loss: 0.03329, valid loss: 0.06756
# [Epoch 24] train loss: 0.03681, valid loss: 0.05173
# [Epoch 25] train loss: 0.03490, valid loss: 0.03263
# +++++ Saved as Best-Epoch: 25 ++++++
# [Epoch 26] train loss: 0.03382, valid loss: 0.03881
# [Epoch 27] train loss: 0.03535, valid loss: 0.04148
# [Epoch 28] train loss: 0.03904, valid loss: 0.03725
# [Epoch 29] train loss: 0.04504, valid loss: 0.04648
# [Epoch 30] train loss: 0.04421, valid loss: 0.03316
# [Epoch 31] train loss: 0.03567, valid loss: 0.03209
# +++++ Saved as Best-Epoch: 31 ++++++
# [Epoch 32] train loss: 0.03396, valid loss: 0.03164
# +++++ Saved as Best-Epoch: 32 ++++++
# [Epoch 33] train loss: 0.03072, valid loss: 0.03322
# [Epoch 34] train loss: 0.02962, valid loss: 0.03406
# [Epoch 35] train loss: 0.02842, valid loss: 0.02930
# +++++ Saved as Best-Epoch: 35 ++++++
# [Epoch 36] train loss: 0.02976, valid loss: 0.03092
# [Epoch 37] train loss: 0.03678, valid loss: 0.02836
# +++++ Saved as Best-Epoch: 37 ++++++
# [Epoch 38] train loss: 0.03229, valid loss: 0.03625
# [Epoch 39] train loss: 0.02912, valid loss: 0.04535
# [Epoch 40] train loss: 0.03599, valid loss: 0.04985
# [Epoch 41] train loss: 0.02974, valid loss: 0.02890
# [Epoch 42] train loss: 0.02725, valid loss: 0.02946
# [Epoch 43] train loss: 0.03189, valid loss: 0.02827
# +++++ Saved as Best-Epoch: 43 ++++++
# [Epoch 44] train loss: 0.02543, valid loss: 0.03397
# [Epoch 45] train loss: 0.02543, valid loss: 0.02981
# [Epoch 46] train loss: 0.02647, valid loss: 0.02813
# +++++ Saved as Best-Epoch: 46 ++++++
# [Epoch 47] train loss: 0.02603, valid loss: 0.02988
# [Epoch 48] train loss: 0.02420, valid loss: 0.02849
# [Epoch 49] train loss: 0.02494, valid loss: 0.02752
# +++++ Saved as Best-Epoch: 49 ++++++
# [Epoch 50] train loss: 0.02600, valid loss: 0.02808
# [Epoch 51] train loss: 0.02537, valid loss: 0.02746
# +++++ Saved as Best-Epoch: 51 ++++++
# [Epoch 52] train loss: 0.02378, valid loss: 0.02926
# [Epoch 53] train loss: 0.02568, valid loss: 0.02725
# +++++ Saved as Best-Epoch: 53 ++++++
# [Epoch 54] train loss: 0.02471, valid loss: 0.02761
# [Epoch 55] train loss: 0.02314, valid loss: 0.02773
# [Epoch 56] train loss: 0.02720, valid loss: 0.02603
# +++++ Saved as Best-Epoch: 56 ++++++
# [Epoch 57] train loss: 0.02956, valid loss: 0.05435
# [Epoch 58] train loss: 0.03823, valid loss: 0.07494
# [Epoch 59] train loss: 0.04005, valid loss: 0.05321
# [Epoch 60] train loss: 0.03025, valid loss: 0.03495
# [Epoch 61] train loss: 0.02522, valid loss: 0.03289
# [Epoch 62] train loss: 0.03131, valid loss: 0.04206
# [Epoch 63] train loss: 0.03879, valid loss: 0.03059
# [Epoch 64] train loss: 0.03408, valid loss: 0.02888
# [Epoch 65] train loss: 0.03023, valid loss: 0.02837
# [Epoch 66] train loss: 0.02833, valid loss: 0.03281
# [Epoch 67] train loss: 0.03087, valid loss: 0.02832
# [Epoch 68] train loss: 0.02420, valid loss: 0.03034
# [Epoch 69] train loss: 0.02212, valid loss: 0.02825
# [Epoch 70] train loss: 0.02158, valid loss: 0.02567
# +++++ Saved as Best-Epoch: 70 ++++++
# [Epoch 71] train loss: 0.02080, valid loss: 0.02546
# +++++ Saved as Best-Epoch: 71 ++++++
# [Epoch 72] train loss: 0.02031, valid loss: 0.02626
# [Epoch 73] train loss: 0.02053, valid loss: 0.02761
# [Epoch 74] train loss: 0.02000, valid loss: 0.02793
# [Epoch 75] train loss: 0.02187, valid loss: 0.02670
# [Epoch 76] train loss: 0.02077, valid loss: 0.02672
# [Epoch 77] train loss: 0.02188, valid loss: 0.02516
# +++++ Saved as Best-Epoch: 77 ++++++
# [Epoch 78] train loss: 0.02143, valid loss: 0.03523
# [Epoch 79] train loss: 0.02509, valid loss: 0.03257
# [Epoch 80] train loss: 0.02184, valid loss: 0.02665
# [Epoch 81] train loss: 0.02084, valid loss: 0.02683
# [Epoch 82] train loss: 0.02177, valid loss: 0.03093
# [Epoch 83] train loss: 0.02051, valid loss: 0.02503
# +++++ Saved as Best-Epoch: 83 ++++++
# [Epoch 84] train loss: 0.01922, valid loss: 0.02947
# [Epoch 85] train loss: 0.02028, valid loss: 0.03250
# [Epoch 86] train loss: 0.02130, valid loss: 0.02473
# +++++ Saved as Best-Epoch: 86 ++++++
# [Epoch 87] train loss: 0.02182, valid loss: 0.02501
# [Epoch 88] train loss: 0.01937, valid loss: 0.02827
# [Epoch 89] train loss: 0.01917, valid loss: 0.02503
# [Epoch 90] train loss: 0.02000, valid loss: 0.02769
# [Epoch 91] train loss: 0.01940, valid loss: 0.02631
# [Epoch 92] train loss: 0.01930, valid loss: 0.02695
# [Epoch 93] train loss: 0.02000, valid loss: 0.02575
# [Epoch 94] train loss: 0.02838, valid loss: 0.02638
# [Epoch 95] train loss: 0.02617, valid loss: 0.03332
# [Epoch 96] train loss: 0.02670, valid loss: 0.02557
# [Epoch 97] train loss: 0.02370, valid loss: 0.02830
# [Epoch 98] train loss: 0.01897, valid loss: 0.03293
# [Epoch 99] train loss: 0.02021, valid loss: 0.02737
# =======================================
#   Best epoch: 86, valid loss: 0.02473
# =======================================
#   0%|          | 0/100 [00:00<?, ?it/s]
# [Epoch 0] train loss: 2.62957, valid loss: 0.22691
# +++++ Saved as Best-Epoch: 0 ++++++
# [Epoch 1] train loss: 0.17307, valid loss: 0.09138
# +++++ Saved as Best-Epoch: 1 ++++++
# [Epoch 2] train loss: 0.11809, valid loss: 0.10048
# [Epoch 3] train loss: 0.11613, valid loss: 0.10792
# [Epoch 4] train loss: 0.10665, valid loss: 0.08623
# +++++ Saved as Best-Epoch: 4 ++++++
# [Epoch 5] train loss: 0.10179, valid loss: 0.08480
# +++++ Saved as Best-Epoch: 5 ++++++
# [Epoch 6] train loss: 0.10069, valid loss: 0.09317
# [Epoch 7] train loss: 0.10485, valid loss: 0.08246
# +++++ Saved as Best-Epoch: 7 ++++++
# [Epoch 8] train loss: 0.09451, valid loss: 0.07488
# +++++ Saved as Best-Epoch: 8 ++++++
# [Epoch 9] train loss: 0.08581, valid loss: 0.07372
# +++++ Saved as Best-Epoch: 9 ++++++
# [Epoch 10] train loss: 0.08301, valid loss: 0.05901
# +++++ Saved as Best-Epoch: 10 ++++++
# [Epoch 11] train loss: 0.07479, valid loss: 0.05707
# +++++ Saved as Best-Epoch: 11 ++++++
# [Epoch 12] train loss: 0.05852, valid loss: 0.05126
# +++++ Saved as Best-Epoch: 12 ++++++
# [Epoch 13] train loss: 0.05006, valid loss: 0.06844
# [Epoch 14] train loss: 0.04553, valid loss: 0.04043
# +++++ Saved as Best-Epoch: 14 ++++++
# [Epoch 15] train loss: 0.04560, valid loss: 0.04778
# [Epoch 16] train loss: 0.04426, valid loss: 0.03660
# +++++ Saved as Best-Epoch: 16 ++++++
# [Epoch 17] train loss: 0.04084, valid loss: 0.05490
# [Epoch 18] train loss: 0.04736, valid loss: 0.03832
# [Epoch 19] train loss: 0.04617, valid loss: 0.03893
# [Epoch 20] train loss: 0.04326, valid loss: 0.04029
# [Epoch 21] train loss: 0.03836, valid loss: 0.03387
# +++++ Saved as Best-Epoch: 21 ++++++
# [Epoch 22] train loss: 0.04106, valid loss: 0.03159
# +++++ Saved as Best-Epoch: 22 ++++++
# [Epoch 23] train loss: 0.03971, valid loss: 0.02991
# +++++ Saved as Best-Epoch: 23 ++++++
# [Epoch 24] train loss: 0.03247, valid loss: 0.02864
# +++++ Saved as Best-Epoch: 24 ++++++
# [Epoch 25] train loss: 0.03304, valid loss: 0.02924
# [Epoch 26] train loss: 0.03431, valid loss: 0.03379
# [Epoch 27] train loss: 0.03435, valid loss: 0.02919
# [Epoch 28] train loss: 0.03559, valid loss: 0.02824
# +++++ Saved as Best-Epoch: 28 ++++++
# [Epoch 29] train loss: 0.03269, valid loss: 0.05142
# [Epoch 30] train loss: 0.04572, valid loss: 0.02678
# +++++ Saved as Best-Epoch: 30 ++++++
# [Epoch 31] train loss: 0.03127, valid loss: 0.02689
# [Epoch 32] train loss: 0.02760, valid loss: 0.02873
# [Epoch 33] train loss: 0.02813, valid loss: 0.02795
# [Epoch 34] train loss: 0.03127, valid loss: 0.02856
# [Epoch 35] train loss: 0.02987, valid loss: 0.03905
# [Epoch 36] train loss: 0.03297, valid loss: 0.02621
# +++++ Saved as Best-Epoch: 36 ++++++
# [Epoch 37] train loss: 0.02971, valid loss: 0.02787
# [Epoch 38] train loss: 0.02459, valid loss: 0.02728
# [Epoch 39] train loss: 0.02442, valid loss: 0.02645
# [Epoch 40] train loss: 0.02452, valid loss: 0.02936
# [Epoch 41] train loss: 0.02461, valid loss: 0.02572
# +++++ Saved as Best-Epoch: 41 ++++++
# [Epoch 42] train loss: 0.02400, valid loss: 0.05632
# [Epoch 43] train loss: 0.03196, valid loss: 0.03132
# [Epoch 44] train loss: 0.02747, valid loss: 0.03130
# [Epoch 45] train loss: 0.02184, valid loss: 0.03077
# [Epoch 46] train loss: 0.02328, valid loss: 0.02872
# [Epoch 47] train loss: 0.02200, valid loss: 0.02875
# [Epoch 48] train loss: 0.02213, valid loss: 0.03085
# [Epoch 49] train loss: 0.02256, valid loss: 0.03024
# [Epoch 50] train loss: 0.02234, valid loss: 0.03185
# [Epoch 51] train loss: 0.03018, valid loss: 0.03305
# [Epoch 52] train loss: 0.02908, valid loss: 0.02778
# [Epoch 53] train loss: 0.02449, valid loss: 0.03504
# [Epoch 54] train loss: 0.02694, valid loss: 0.02987
# [Epoch 55] train loss: 0.02379, valid loss: 0.03837
# [Epoch 56] train loss: 0.02739, valid loss: 0.03283
# [Epoch 57] train loss: 0.02266, valid loss: 0.02789
# [Epoch 58] train loss: 0.02153, valid loss: 0.03041
# [Epoch 59] train loss: 0.02030, valid loss: 0.02940
# [Epoch 60] train loss: 0.01989, valid loss: 0.03481
# [Epoch 61] train loss: 0.02283, valid loss: 0.03108
# [Epoch 62] train loss: 0.02369, valid loss: 0.03027
# [Epoch 63] train loss: 0.02067, valid loss: 0.02851
# [Epoch 64] train loss: 0.01940, valid loss: 0.03632
# [Epoch 65] train loss: 0.02508, valid loss: 0.02821
# [Epoch 66] train loss: 0.02392, valid loss: 0.02774
# [Epoch 67] train loss: 0.02159, valid loss: 0.03329
# [Epoch 68] train loss: 0.02010, valid loss: 0.03468
# [Epoch 69] train loss: 0.01897, valid loss: 0.03066
# [Epoch 70] train loss: 0.01908, valid loss: 0.03061
# [Epoch 71] train loss: 0.01853, valid loss: 0.03441
# [Epoch 72] train loss: 0.01855, valid loss: 0.03004
# [Epoch 73] train loss: 0.01811, valid loss: 0.02934
# [Epoch 74] train loss: 0.01811, valid loss: 0.03034
# [Epoch 75] train loss: 0.01842, valid loss: 0.03102
# [Epoch 76] train loss: 0.02000, valid loss: 0.04222
# [Epoch 77] train loss: 0.02486, valid loss: 0.03269
# [Epoch 78] train loss: 0.02195, valid loss: 0.03116
# [Epoch 79] train loss: 0.02122, valid loss: 0.02936
# [Epoch 80] train loss: 0.02048, valid loss: 0.03273
# [Epoch 81] train loss: 0.02131, valid loss: 0.03216
# [Epoch 82] train loss: 0.01874, valid loss: 0.02832
# [Epoch 83] train loss: 0.01789, valid loss: 0.03039
# [Epoch 84] train loss: 0.02075, valid loss: 0.03056
# [Epoch 85] train loss: 0.02122, valid loss: 0.03307
# [Epoch 86] train loss: 0.01949, valid loss: 0.03910
# [Epoch 87] train loss: 0.02220, valid loss: 0.03581
# [Epoch 88] train loss: 0.02307, valid loss: 0.03044
# [Epoch 89] train loss: 0.02048, valid loss: 0.03119
# [Epoch 90] train loss: 0.02039, valid loss: 0.03028
# [Epoch 91] train loss: 0.01976, valid loss: 0.03153
# [Epoch 92] train loss: 0.02028, valid loss: 0.03055
# [Epoch 93] train loss: 0.01867, valid loss: 0.03102
# [Epoch 94] train loss: 0.01782, valid loss: 0.02971
# [Epoch 95] train loss: 0.01712, valid loss: 0.03018
# [Epoch 96] train loss: 0.01703, valid loss: 0.03262
# [Epoch 97] train loss: 0.01850, valid loss: 0.03089
# [Epoch 98] train loss: 0.01806, valid loss: 0.03098
# [Epoch 99] train loss: 0.01694, valid loss: 0.03079
# =======================================
#   Best epoch: 41, valid loss: 0.02572
# =======================================

# %%
fig = plt.figure(figsize=(25, 5))
for i in range(num_splits):
    ax = fig.add_subplot(1, num_splits, i+1)
    ax.plot(history[i]["train"], label="train loss")
    ax.plot(history[i]["valid"], label="valid loss")
    ax.set_title(f"Fold {i}")
    ax.set_ylim([0.01, 1.1])
    ax.set_yscale("log")
    ax.legend()
plt.show()

# %%
sample_id_1 = 1
sample_id_2 = 9
plt.plot(pred_results[0]["true"][sample_id_1][0], label="true 1", color="C1")
plt.plot(pred_results[0]["pred"][sample_id_1][0], label="pred 1", color="orange")
plt.plot((pred_results[0]["pred"][sample_id_1][0] - 1) * -1, label="pred 1 reversed", ls="--", color="orange")


plt.plot(pred_results[0]["true"][sample_id_2][0], label="true 2", color="blue")
plt.plot(pred_results[0]["pred"][sample_id_2][0], label="pred 2", color="blue", alpha=0.3)
plt.plot((pred_results[0]["pred"][sample_id_2][0] - 1) * -1, label="pred 2 reversed", color="blue", ls="--", alpha=0.3)

plt.legend()

# %% [markdown]
# ## 学習データと予測値

# %%
sample_id_1 = 1

sample_x = train_x[sample_id_1, :, :].transpose(1, 0).reshape(1, 16, 1000)
sample_y = train_y[sample_id_1, :, 0]
plt.plot(sample_y, label="True")
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")
    model.to("cpu")
    pred_y = model(torch.tensor(sample_x, dtype=torch.float32)).detach().numpy()

    plt.plot(pred_y[0], label=f"Pred (Fold {i})", ls="--")

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_59044/828188601.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")

# %%
sample_id_1 = 8

sample_x = train_x[sample_id_1, :, :].transpose(1, 0).reshape(1, 16, 1000)
sample_y = train_y[sample_id_1, :, axis]
plt.plot(sample_y, label="True")
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")
    model.to("cpu")
    pred_y = model(torch.tensor(sample_x, dtype=torch.float32)).detach().numpy()

    plt.plot(pred_y[0], label=f"Pred (Fold {i})", ls="--")

plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_59044/1007387240.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis0_BestEpoch.pt")

# %% [markdown]
# ## 評価データと予測値

# %%
from sklearn.metrics import mean_absolute_error

def show_test_pred(sample_id: int=0):
    sample_x = test_x[sample_id, :, :].transpose(1, 0).reshape(1, 16, 1000)
    sample_y = test_y[sample_id, :, axis]
    preds = []
    fig = plt.figure(figsize=(12, 5))
    plt.plot(sample_y, label="True", lw=2, color="black")
    for i in range(num_splits):
        model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
        model.to("cpu")
        pred_y = model(torch.tensor(sample_x, dtype=torch.float32)).detach().numpy()
        preds.append(pred_y[0])
        plt.plot(pred_y[0], label=f"Pred (Fold {i})", ls="--", color=f"C{i+1}")
        plt.plot((pred_y[0]-1)*-1, label=f"Pred (Fold {i}, reversed)", ls="-.", color=f"C{i+1}")
    
    mean_pred = (np.mean(preds, axis=0)) 
    pred_rev = (mean_pred-1)*-1
    plt.plot(mean_pred, label="Mean", color="Blue", lw=1.5)
    plt.plot(pred_rev, label="Mean (reversed)", color="Red", lw=1.5)

    mean_error = mean_absolute_error(sample_y, mean_pred)
    mean_rev_error = mean_absolute_error(sample_y, pred_rev)
    plt.legend()
    plt.title(f"Sample: {sample_id}, Mean: {mean_error:.5f}, Rev: {mean_rev_error:.5f}")
    plt.show()
    
    

for i in [0, 9, 318]:
    show_test_pred(i)
# Out:
# /tmp/ipykernel_59044/2305665677.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# /tmp/ipykernel_59044/2305665677.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# /tmp/ipykernel_59044/2305665677.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")

# %%
axis = 0
preds = []
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
    model.to(device)
    pred_in_fold = []
    with torch.no_grad():
        for x, y in zip(test_x, test_y):
            x = x.transpose(1, 0).reshape(1, 16, 1000)
            x = torch.tensor(x, dtype=torch.float32)
            x = x.to(device)
            pred = model(x)
            pred = pred.to("cpu")
            pred = pred.detach().numpy()
            pred_in_fold.append(pred)

    preds.append(np.array(pred_in_fold))

mean_pred = np.mean(preds, axis=0).reshape(-1, 30)
rev_pred = (mean_pred - 1) * -1
mean_loss = mean_absolute_error(test_y[:, :, axis], mean_pred)
rev_loss = mean_absolute_error(test_y[:, :, axis], rev_pred)

print(
f"""
Mean     : {mean_loss:.5f}
Reversed : {rev_loss:.5f} 
"""
)
# Out:
# /tmp/ipykernel_59044/3545400414.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# Mean     : 0.38048
# Reversed : 0.26799

# %%
axis = 1
preds = []
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
    model.to(device)
    pred_in_fold = []
    with torch.no_grad():
        for x, y in zip(test_x, test_y):
            x = x.transpose(1, 0).reshape(1, 16, 1000)
            x = torch.tensor(x, dtype=torch.float32)
            x = x.to(device)
            pred = model(x)
            pred = pred.to("cpu")
            pred = pred.detach().numpy()
            pred_in_fold.append(pred)

    preds.append(np.array(pred_in_fold))

mean_pred = np.mean(preds, axis=0).reshape(-1, 30)
rev_pred = (mean_pred - 1) * -1
mean_loss = mean_absolute_error(test_y[:, :, axis], mean_pred)
rev_loss = mean_absolute_error(test_y[:, :, axis], rev_pred)

print(
f"""
Mean     : {mean_loss:.5f}
Reversed : {rev_loss:.5f} 
"""
)
# Out:
# /tmp/ipykernel_59044/1523580880.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# Mean     : 0.22193
# Reversed : 0.14286

# %%
axis = 2
preds = []
for i in range(num_splits):
    model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
    model.to(device)
    pred_in_fold = []
    with torch.no_grad():
        for x, y in zip(test_x, test_y):
            x = x.transpose(1, 0).reshape(1, 16, 1000)
            x = torch.tensor(x, dtype=torch.float32)
            x = x.to(device)
            pred = model(x)
            pred = pred.to("cpu")
            pred = pred.detach().numpy()
            pred_in_fold.append(pred)

    preds.append(np.array(pred_in_fold))

mean_pred = np.mean(preds, axis=0).reshape(-1, 30)
rev_pred = (mean_pred - 1) * -1
mean_loss = mean_absolute_error(test_y[:, :, axis], mean_pred)
rev_loss = mean_absolute_error(test_y[:, :, axis], rev_pred)

print(
f"""
Mean     : {mean_loss:.5f}
Reversed : {rev_loss:.5f} 
"""
)
# Out:
# /tmp/ipykernel_59044/3322386290.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(f"../models/Fold{i}_Axis{axis}_BestEpoch.pt")
# Mean     : 0.19402
# Reversed : 0.19670
